# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from imports.database import Database
from imports.constants import MEGA_STONES

def carregar_e_atualizar_dados():
    db = Database()
    mega_stones = ", ".join(f"'{stone}'" for stone in MEGA_STONES)

    query = f"""
    SELECT
        i.name AS mega_stone,
        ROUND(
            100.0 * SUM(t.wins)
            / NULLIF(SUM(t.wins) + SUM(t.losses), 0),
            2
        ) AS winrate,
        ROUND(
            100.0 * COUNT(*) /
            (SELECT COUNT(*) FROM Teams),
            2
        ) AS usage_percent
    FROM Pokemon_teams pt
    JOIN Items i ON pt.item_id = i.id
    JOIN Teams t ON pt.team_id = t.id
    WHERE
        i.name IN ({mega_stones})
    GROUP BY i.name
    HAVING COUNT(*) >= 20
    ORDER BY usage_percent DESC;
    """
    
    print("Conectando ao banco e buscando dados de Mega Stones...")
    with db.connect() as cursor:
        conexao = cursor._connection
        df_local = pd.read_sql_query(query, conexao)
    
    csv_path = "../sql/megas_usagexwinrate.csv"
    df_local.to_csv(csv_path, index=False)
    print(f"CSV atualizado com sucesso em: {csv_path}")
    
    return df_local

df = carregar_e_atualizar_dados()

plt.style.use('dark_background')
plt.figure(figsize=(14, 9))

sns.set_theme(style="darkgrid", rc={
    "axes.facecolor": "#121212", 
    "figure.facecolor": "#121212",
    "text.color": "white", 
    "axes.labelcolor": "white",
    "xtick.color": "white", 
    "ytick.color": "white",
    "grid.color": "#262626"
})

scatter = plt.scatter(
    df["usage_percent"],
    df["winrate"],
    c=df["winrate"],
    cmap="plasma",
    alpha=0.85,
    s=85,
    edgecolors="white",
    linewidths=0.7
)

cbar = plt.colorbar(scatter)
cbar.set_label("Escala de Winrate (%)", color="white", weight="bold")
cbar.ax.yaxis.set_tick_params(color="white")

for _, row in df.iterrows():
    plt.annotate(
        row["mega_stone"],
        (row["usage_percent"], row["winrate"]),
        textcoords="offset points",
        xytext=(6, 6),
        fontsize=8,
        color="#E0E0E0"
    )

usage_mean = df["usage_percent"].mean()
winrate_mean = df["winrate"].mean()

plt.axvline(usage_mean, linestyle="--", linewidth=1.5, color="#555555", alpha=0.8)
plt.axhline(winrate_mean, linestyle="--", linewidth=1.5, color="#555555", alpha=0.8)

plt.text(usage_mean + 0.2, winrate_mean + 0.2, "HiU / HiW", fontsize=10, weight='bold', color="#F1C40F")
plt.text(df["usage_percent"].min(), winrate_mean + 0.2, "LoU / HiW", fontsize=10, weight='bold', color="#F1C40F")
plt.text(usage_mean + 0.2, df["winrate"].min(), "HiU / LoW", fontsize=10, weight='bold', color="#F1C40F")
plt.text(df["usage_percent"].min(), df["winrate"].min(), "LoU / LoW", fontsize=10, weight='bold', color="#F1C40F")

plt.xlabel("Usage %", weight="bold", fontsize=11, labelpad=10)
plt.ylabel("Winrate %", weight="bold", fontsize=11, labelpad=10)
plt.title("Mega Pokémon: Taxa de uso vs Taxa de Vitória", fontsize=14, weight="bold", pad=20)
plt.grid(True, linestyle="--", alpha=0.15)

plt.tight_layout()
plt.show()
# Out:
# Conectando ao banco e buscando dados de Mega Stones...
# CSV atualizado com sucesso em: ../sql/megas_usagexwinrate.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
from imports.database import Database
from imports.constants import MEGA_STONES

def carregar_e_atualizar_dados_tipos():
    db = Database()
    mega_stones = ", ".join(f"'{stone}'" for stone in MEGA_STONES)
    
    query = f"""
    WITH BaseMegaTeams AS (
        SELECT 
            pt.team_id,
            t.wins,
            t.losses,
            pd.type1,
            pd.type2
        FROM Pokemon_teams pt
        JOIN Items i ON pt.item_id = i.id
        JOIN Teams t ON pt.team_id = t.id
        JOIN Pokemons p ON pt.pokemon_id = p.id
        JOIN Pokemon_mapping pm ON p.id = pm.pokemon_scraper_id
        JOIN Pokemon_data pd ON pm.pokemon_api_id = pd.id
        WHERE 
            i.name IN ({mega_stones})
    ),
    TypesUnfurl AS (
        SELECT team_id, wins, losses, type1 AS pokemon_type FROM BaseMegaTeams WHERE type1 IS NOT NULL
        UNION ALL
        SELECT team_id, wins, losses, type2 AS pokemon_type FROM BaseMegaTeams WHERE type2 IS NOT NULL
    )
    SELECT
        pokemon_type,
        ROUND(
            100.0 * SUM(wins)
            / NULLIF(SUM(wins) + SUM(losses), 0),
            2
        ) AS winrate,
        ROUND(
            100.0 * COUNT(DISTINCT team_id) /
            (SELECT COUNT(*) FROM Teams),
            2
        ) AS usage_percent
    FROM TypesUnfurl
    GROUP BY pokemon_type
    ORDER BY usage_percent DESC;
    """
    
    print("Conectando ao banco e processando dados por Tipo de Mega...")
    with db.connect() as cursor:
        conexao = cursor._connection
        df_local = pd.read_sql_query(query, conexao)
        
    csv_path = "../sql/types_megas_usagexwinrate.csv"
    df_local.to_csv(csv_path, index=False)
    print(f"Novo CSV de tipos atualizado com sucesso em: {csv_path}")
    
    return df_local

df = carregar_e_atualizar_dados_tipos()

plt.figure(figsize=(14, 9))

plt.scatter(
    df["usage_percent"],
    df["winrate"],
    alpha=0.8,
    color="crimson",
    s=80
)

for _, row in df.iterrows():
    plt.annotate(
        row["pokemon_type"].capitalize(),
        (row["usage_percent"], row["winrate"]),
        textcoords="offset points",
        xytext=(6, 6),
        fontsize=9,
        weight='bold'
    )

usage_mean = df["usage_percent"].mean()
winrate_mean = df["winrate"].mean()

plt.axvline(usage_mean, linestyle="--", linewidth=1.5, color="gray")
plt.axhline(winrate_mean, linestyle="--", linewidth=1.5, color="gray")

plt.text(usage_mean + 0.05, winrate_mean + 0.2, "HiU / HiW", fontsize=10, weight='bold')
plt.text(df["usage_percent"].min(), winrate_mean + 0.2, "LoU / HiW", fontsize=10, weight='bold')
plt.text(usage_mean + 0.05, df["winrate"].min(), "HiU / LoW", fontsize=10, weight='bold')
plt.text(df["usage_percent"].min(), df["winrate"].min(), "LoU / LoW", fontsize=10, weight='bold')

plt.xlabel("Usage % (Por Tipo)")
plt.ylabel("Winrate % (Por Tipo)")
plt.title("Mega Evoluções: Performance por Tipo Elemental")
plt.grid(True, linestyle="--", alpha=0.3)

plt.show()
# Out:
# Conectando ao banco e processando dados por Tipo de Mega...
# Novo CSV de tipos atualizado com sucesso em: ../sql/types_megas_usagexwinrate.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
from imports.database import Database
from imports.constants import MEGA_STONES

def carregar_e_atualizar_dados_speed():
    db = Database()
    mega_stones = ", ".join(f"'{stone}'" for stone in MEGA_STONES)
    
    query = f"""
    SELECT
        i.name AS mega_stone,
        MAX(pd.speed) AS base_speed,
        ROUND(
            100.0 * SUM(t.wins)
            / NULLIF(SUM(t.wins) + SUM(t.losses), 0),
            2
        ) AS winrate,
        ROUND(
            100.0 * COUNT(*) /
            (SELECT COUNT(*) FROM Teams),
            2
        ) AS usage_percent
    FROM Pokemon_teams pt
    JOIN Items i ON pt.item_id = i.id
    JOIN Teams t ON pt.team_id = t.id
    JOIN Pokemons p ON pt.pokemon_id = p.id
    JOIN Pokemon_mapping pm ON p.id = pm.pokemon_scraper_id
    JOIN Pokemon_data pd ON pm.pokemon_api_id = pd.id
    WHERE
        i.name IN ({mega_stones})
    GROUP BY i.name
    HAVING COUNT(*) >= 20
    ORDER BY base_speed DESC;
    """
    
    print("Conectando ao banco e buscando atributos de Speed das Megas...")
    with db.connect() as cursor:
        conexao = cursor._connection
        df_local = pd.read_sql_query(query, conexao)
        
    csv_path = "../sql/megas_speed_performance.csv"
    df_local.to_csv(csv_path, index=False)
    print(f"Novo CSV de velocidade atualizado em: {csv_path}")
    
    return df_local

df = carregar_e_atualizar_dados_speed()

fig, ax1 = plt.subplots(figsize=(15, 8))
fig.patch.set_facecolor('#202225')
ax1.set_facecolor('#2f3136')

cor_barra = "#5c8a9d"
cor_linha = "#ff9a76"
cor_grade = "#40444b"
cor_texto = "#eeeeee"

ax1.set_xlabel("Mega Stone (Item)", color=cor_texto, fontsize=11, labelpad=12)
ax1.set_ylabel("Base Speed", color=cor_barra, weight="bold", fontsize=11)
barras = ax1.bar(df["mega_stone"], df["base_speed"], color=cor_barra, alpha=0.8, width=0.55, label="Base Speed")
ax1.tick_params(axis="y", labelcolor=cor_barra, colors=cor_texto)
ax1.set_xticklabels(df["mega_stone"], rotation=45, ha="right", fontsize=9, color=cor_texto)
ax1.grid(True, linestyle="--", color=cor_grade, alpha=0.7)

ax2 = ax1.twinx()  
ax2.set_ylabel("Winrate %", color=cor_linha, weight="bold", fontsize=11)
linha = ax2.plot(df["mega_stone"], df["winrate"], color=cor_linha, marker="o", markersize=6, linewidth=2, alpha=0.9, label="Winrate %")
ax2.tick_params(axis="y", labelcolor=cor_linha, colors=cor_texto)

winrate_medio = df["winrate"].mean()
ax2.axhline(winrate_medio, linestyle=":", linewidth=1.5, color="#b9bbbe", alpha=0.5)
ax2.text(len(df)-0.6, winrate_medio + 0.5, f"Média: {winrate_medio:.1f}%", color="#b9bbbe", ha="right", fontsize=9)

ax2.grid(False)

plt.title("Impacto da Velocidade Base na Taxa de Vitória das Mega Evoluções", fontsize=14, weight="bold", pad=20, color=cor_texto)
fig.tight_layout()
plt.show()
# Out:
# Conectando ao banco e buscando atributos de Speed das Megas...
# Novo CSV de velocidade atualizado em: ../sql/megas_speed_performance.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from imports.database import Database
from imports.constants import MEGA_STONES

def carregar_e_atualizar_dados_estilos():
    db = Database()
    mega_stones = ", ".join(f"'{stone}'" for stone in MEGA_STONES)
    
    query = f"""
    WITH MegaStats AS (
        SELECT
            i.name AS mega_stone,
            pd.attack,
            pd.special_attack,
            ROUND(
                100.0 * SUM(t.wins)
                / NULLIF(SUM(t.wins) + SUM(t.losses), 0),
                2
            ) AS winrate,
            ROUND(
                100.0 * COUNT(*) /
                (SELECT COUNT(*) FROM Teams),
                2
            ) AS usage_percent
        FROM Pokemon_teams pt
        JOIN Items i ON pt.item_id = i.id
        JOIN Teams t ON pt.team_id = t.id
        JOIN Pokemons p ON pt.pokemon_id = p.id
        JOIN Pokemon_mapping pm ON p.id = pm.pokemon_scraper_id
        JOIN Pokemon_data pd ON pm.pokemon_api_id = pd.id
        WHERE
            i.name IN ({mega_stones})
        GROUP BY i.name, pd.attack, pd.special_attack
        HAVING COUNT(*) >= 20
    ),
    CategorizedMegas AS (
        SELECT
            winrate,
            usage_percent,
            CASE 
                WHEN (attack - special_attack) > 20 THEN 'Físico'
                WHEN (special_attack - attack) > 20 THEN 'Especial'
                ELSE 'Híbrido'
            END AS atacante_tipo
        FROM MegaStats
    )
    SELECT
        atacante_tipo,
        ROUND(AVG(winrate), 2) AS avg_winrate,
        ROUND(AVG(usage_percent), 2) AS avg_usage
    FROM CategorizedMegas
    GROUP BY atacante_tipo
    ORDER BY avg_usage DESC;
    """
    
    print("Conectando ao banco e classificando as Megas por estilo de ataque...")
    with db.connect() as cursor:
        conexao = cursor._connection
        df_local = pd.read_sql_query(query, conexao)
        
    csv_path = "../sql/megas_attack_style_performance.csv"
    df_local.to_csv(csv_path, index=False)
    print(f"Novo CSV de estilos de ataque atualizado em: {csv_path}")
    
    return df_local

df = carregar_e_atualizar_dados_estilos()

categorias = df["atacante_tipo"].tolist()
valores_uso = df["avg_usage"].tolist()
valores_vitoria = df["avg_winrate"].tolist()

x = np.arange(len(categorias))
largura = 0.35

fig, ax1 = plt.subplots(figsize=(12, 7))

cor_uso = "mediumpurple"
barra1 = ax1.bar(x - largura/2, valores_uso, largura, label="Uso Médio %", color=cor_uso, alpha=0.8)
ax1.set_ylabel("Uso Médio %", color=cor_uso, weight="bold")
ax1.tick_params(axis="y", labelcolor=cor_uso)
ax1.set_xticks(x)
ax1.set_xticklabels(categorias, fontsize=11, weight="bold")

ax2 = ax1.twinx()

cor_vitoria = "seagreen"
barra2 = ax2.bar(x + largura/2, valores_vitoria, largura, label="Winrate Médio %", color=cor_vitoria, alpha=0.8)
ax2.set_ylabel("Winrate Médio %", color=cor_vitoria, weight="bold")
ax2.tick_params(axis="y", labelcolor=cor_vitoria)

ax2.set_ylim(min(valores_vitoria) - 5, max(valores_vitoria) + 5)

for barra in barra1:
    altura = barra.get_height()
    ax1.annotate(f'{altura}%',
                 xy=(barra.get_x() + barra.get_width() / 2, altura),
                 xytext=(0, 3),  
                 textcoords="offset points",
                 ha='center', va='bottom', fontsize=9, weight="bold")

for barra in barra2:
    altura = barra.get_height()
    ax2.annotate(f'{altura}%',
                 xy=(barra.get_x() + barra.get_width() / 2, altura),
                 xytext=(0, 3),
                 textcoords="offset points",
                 ha='center', va='bottom', fontsize=9, weight="bold")

plt.title("Comparativo de Performance de Mega Evoluções: Físicos vs Especiais vs Híbridos")
fig.tight_layout()
plt.grid(True, linestyle="--", alpha=0.15)

plt.show()
# Out:
# Conectando ao banco e classificando as Megas por estilo de ataque...
# Novo CSV de estilos de ataque atualizado em: ../sql/megas_attack_style_performance.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from imports.database import Database
from imports.constants import MEGA_STONES

def carregar_e_atualizar_dados_quantidade():
    db = Database()
    mega_stones = ", ".join(f"'{stone}'" for stone in MEGA_STONES)
    
    query = f"""
    WITH TeamMegaCount AS (
        SELECT
            t.id AS team_id,
            t.wins,
            t.losses,
            COUNT(pt.pokemon_id) AS mega_count
        FROM Teams t
        JOIN Pokemon_teams pt ON t.id = pt.team_id
        JOIN Items i ON pt.item_id = i.id
        WHERE
            i.name IN ({mega_stones})
        GROUP BY t.id, t.wins, t.losses
    ),
    CategorizedTeams AS (
        SELECT
            wins,
            losses,
            CASE 
                WHEN mega_count = 1 THEN '1 Mega no Time'
                ELSE '2 ou+ Megas no Time'
            END AS qtd_megas
        FROM TeamMegaCount
    ),
    MetricsPerCategory AS (
        SELECT
            qtd_megas,
            ROUND(
                100.0 * SUM(wins)
                / NULLIF(SUM(wins) + SUM(losses), 0),
                2
            ) AS winrate,
            ROUND(
                100.0 * COUNT(*) /
                (SELECT COUNT(*) FROM Teams),
                2
            ) AS usage_percent
        FROM CategorizedTeams
        GROUP BY qtd_megas
    )
    SELECT * FROM MetricsPerCategory
    ORDER BY usage_percent DESC;
    """
    
    print("Conectando ao banco e contando Megas por time...")
    with db.connect() as cursor:
        conexao = cursor._connection
        df_local = pd.read_sql_query(query, conexao)
        
    csv_path = "../sql/megas_count_performance.csv"
    df_local.to_csv(csv_path, index=False)
    print(f"Novo CSV de quantidade de Megas atualizado em: {csv_path}")
    
    return df_local

df = carregar_e_atualizar_dados_quantidade()

categorias = df["qtd_megas"].tolist()
valores_uso = df["usage_percent"].tolist()
valores_vitoria = df["winrate"].tolist()

x = np.arange(len(categorias))
largura = 0.35

fig, ax1 = plt.subplots(figsize=(10, 6))

cor_uso = "royalblue"
barra1 = ax1.bar(x - largura/2, valores_uso, largura, label="Uso %", color=cor_uso, alpha=0.8)
ax1.set_ylabel("Uso % (Proporção de Todos os Times)", color=cor_uso, weight="bold")
ax1.tick_params(axis="y", labelcolor=cor_uso)
ax1.set_xticks(x)
ax1.set_xticklabels(categorias, fontsize=11, weight="bold")

ax2 = ax1.twinx()

cor_vitoria = "crimson"
barra2 = ax2.bar(x + largura/2, valores_vitoria, largura, label="Winrate %", color=cor_vitoria, alpha=0.8)
ax2.set_ylabel("Winrate %", color=cor_vitoria, weight="bold")
ax2.tick_params(axis="y", labelcolor=cor_vitoria)

ax2.set_ylim(min(valores_vitoria) - 5, max(valores_vitoria) + 5)

for barra in barra1:
    altura = barra.get_height()
    ax1.annotate(f'{altura}%',
                 xy=(barra.get_x() + barra.get_width() / 2, altura),
                 xytext=(0, 3),  
                 textcoords="offset points",
                 ha='center', va='bottom', fontsize=10, weight="bold")

for barra in barra2:
    altura = barra.get_height()
    ax2.annotate(f'{altura}%',
                 xy=(barra.get_x() + barra.get_width() / 2, altura),
                 xytext=(0, 3),
                 textcoords="offset points",
                 ha='center', va='bottom', fontsize=10, weight="bold")

plt.title("Comparativo de Estratégia: 1 Mega vs 2 ou mais Megas por Time")
fig.tight_layout()
plt.grid(True, linestyle="--", alpha=0.15)

plt.show()
# Out:
# Conectando ao banco e contando Megas por time...
# C:\Users\User\AppData\Local\Temp\ipykernel_2860\4066763752.py:61: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_local = pd.read_sql_query(query, conexao)
# Novo CSV de quantidade de Megas atualizado em: ../sql/megas_count_performance.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from imports.database import Database
from imports.constants import MEGA_STONES

def carregar_dados_winrate_counters():
    db = Database()
    mega_stones = ", ".join(f"'{stone}'" for stone in MEGA_STONES)
    
    query = f"""
    WITH BaseStats AS (
        SELECT 
            pt.team_id,
            t.wins,
            t.losses,
            pd.name AS pokemon_name,
            pd.type1,
            pd.type2,
            i.name AS item_name
        FROM Pokemon_teams pt
        JOIN Teams t ON pt.team_id = t.id
        JOIN Items i ON pt.item_id = i.id
        JOIN Pokemon_mapping pm ON pt.pokemon_id = pm.pokemon_scraper_id
        JOIN Pokemon_data pd ON pm.pokemon_api_id = pd.id
        WHERE i.name IN ({mega_stones})
    ),
    Categorias_Stats AS (
        -- 1. Mega Charizard Y
        SELECT 'Mega Charizard Y' AS categoria, 'Charizard Y & Counters' AS grupo, '#FF5733' AS cor, wins, losses FROM BaseStats WHERE LOWER(pokemon_name) LIKE '%charizard%' AND LOWER(item_name) LIKE '%charizardite y'
        UNION ALL
        SELECT 'Megas Pedra' AS categoria, 'Charizard Y & Counters' AS grupo, '#C5B358' AS cor, wins, losses FROM BaseStats WHERE type1 = 'Rock' OR type2 = 'Rock'
        UNION ALL
        SELECT 'Megas Elétrico' AS categoria, 'Charizard Y & Counters' AS grupo, '#FFD700' AS cor, wins, losses FROM BaseStats WHERE type1 = 'Electric' OR type2 = 'Electric'
        UNION ALL
        SELECT 'Megas Água' AS categoria, 'Charizard Y & Counters' AS grupo, '#3399FF' AS cor, wins, losses FROM BaseStats WHERE type1 = 'Water' OR type2 = 'Water'
        
        UNION ALL
        -- 2. Mega Floette
        SELECT 'Mega Floette' AS categoria, 'Mega Floette & Counters' AS grupo, '#FF69B4' AS cor, wins, losses FROM BaseStats WHERE LOWER(pokemon_name) LIKE '%floette%'
        UNION ALL
        SELECT 'Megas Veneno' AS categoria, 'Mega Floette & Counters' AS grupo, '#A020F0' AS cor, wins, losses FROM BaseStats WHERE type1 = 'Poison' OR type2 = 'Poison'
        UNION ALL
        SELECT 'Megas Aço' AS categoria, 'Mega Floette & Counters' AS grupo, '#B8B8B8' AS cor, wins, losses FROM BaseStats WHERE type1 = 'Steel' OR type2 = 'Steel'
        
        UNION ALL
        -- 3. Mega Delphox e suas ameaças (Rock, Water, Ghost, Dark)
        SELECT 'Mega Delphox' AS categoria, 'Mega Delphox & Counters' AS grupo, '#E67E22' AS cor, wins, losses FROM BaseStats WHERE LOWER(pokemon_name) LIKE '%delphox%' AND LOWER(item_name) LIKE '%delphoxite%'
        UNION ALL
        SELECT 'Megas Pedra' AS categoria, 'Mega Delphox & Counters' AS grupo, '#C5B358' AS cor, wins, losses FROM BaseStats WHERE type1 = 'Rock' OR type2 = 'Rock'
        UNION ALL
        SELECT 'Megas Água' AS categoria, 'Mega Delphox & Counters' AS grupo, '#3399FF' AS cor, wins, losses FROM BaseStats WHERE type1 = 'Water' OR type2 = 'Water'
        UNION ALL
        SELECT 'Megas Fantasma' AS categoria, 'Mega Delphox & Counters' AS grupo, '#705898' AS cor, wins, losses FROM BaseStats WHERE type1 = 'Ghost' OR type2 = 'Ghost'
        UNION ALL
        SELECT 'Megas Noturno' AS categoria, 'Mega Delphox & Counters' AS grupo, '#705848' AS cor, wins, losses FROM BaseStats WHERE type1 = 'Dark' OR type2 = 'Dark'
    )
    SELECT 
        categoria,
        grupo,
        cor,
        ROUND(
            100.0 * SUM(wins) / NULLIF(SUM(wins) + SUM(losses), 0), 
            2
        ) AS winrate
    FROM Categorias_Stats
    GROUP BY categoria, grupo, cor;
    """
    
    print("Conectando ao banco e calculando winrates do meta expandido...")
    with db.connect() as cursor:
        conexao = cursor._connection
        df_local = pd.read_sql_query(query, conexao)
        
    csv_path = "../sql/winrate_vs_counters_meta.csv"
    df_local.to_csv(csv_path, index=False)
    print(f"Novo CSV salvo em: {csv_path}")
    
    return df_local

df = carregar_dados_winrate_counters()

plt.style.use('dark_background')
sns.set_theme(style="darkgrid", rc={
    "axes.facecolor": "#121212", 
    "figure.facecolor": "#121212",
    "text.color": "white",
    "axes.labelcolor": "white",
    "xtick.color": "white",
    "ytick.color": "white"
})

fig, axes = plt.subplots(1, 3, figsize=(20, 6), sharey=True)
fig.suptitle('Análise de Meta: Domínio de Charizard e Floette vs. Delphox', fontsize=16, fontweight='bold', color='#FFFFFF', y=1.02)

df_chari = df[df['grupo'] == 'Charizard Y & Counters'].sort_values(by='winrate', ascending=False)
if not df_chari.empty:
    sns.barplot(x='categoria', y='winrate', data=df_chari, palette=df_chari['cor'].tolist(), ax=axes[0], hue='categoria', legend=False)
    axes[0].set_xticklabels(df_chari['categoria'], rotation=20, ha='right', color='white')
axes[0].set_title('O Domínio do Mega Charizard Y', fontsize=13, color='#FF5733', weight='bold', pad=12)
axes[0].set_xlabel('')
axes[0].set_ylabel('Winrate Médio (%)', fontsize=11, weight='bold', color='white')

df_floette = df[df['grupo'] == 'Mega Floette & Counters'].sort_values(by='winrate', ascending=False)
if not df_floette.empty:
    sns.barplot(x='categoria', y='winrate', data=df_floette, palette=df_floette['cor'].tolist(), ax=axes[1], hue='categoria', legend=False)
    axes[1].set_xticklabels(df_floette['categoria'], rotation=20, ha='right', color='white')
axes[1].set_title('A Resiliência da Mega Floette', fontsize=13, color='#FF69B4', weight='bold', pad=12)
axes[1].set_xlabel('')
axes[1].set_ylabel('')

df_delphox = df[df['grupo'] == 'Mega Delphox & Counters'].sort_values(by='winrate', ascending=False)
if not df_delphox.empty:
    sns.barplot(x='categoria', y='winrate', data=df_delphox, palette=df_delphox['cor'].tolist(), ax=axes[2], hue='categoria', legend=False)
    axes[2].set_xticklabels(df_delphox['categoria'], rotation=20, ha='right', color='white')
axes[2].set_title('O Potencial de Mega Delphox', fontsize=13, color='#E67E22', weight='bold', pad=12)
axes[2].set_xlabel('')
axes[2].set_ylabel('')

for ax in axes:
    ax.tick_params(colors='white', which='both')
    for p in ax.patches:
        if p.get_height() > 0:
            ax.annotate(f"{p.get_height():.1f}%", (p.get_x() + p.get_width() / 2., p.get_height() + 1),
                        ha='center', va='center', xytext=(0, 3), textcoords='offset points', fontsize=10, fontweight='bold', color='white')

plt.ylim(0, 100)
plt.tight_layout()

plt.savefig('../sql/winrate_counters_analysis.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# Conectando ao banco e calculando winrates do meta expandido...
# Novo CSV salvo em: ../sql/winrate_vs_counters_meta.csv

# %%
import pandas as pd
import warnings
from imports.database import Database

warnings.filterwarnings("ignore", category=UserWarning)

def analisar_meta_delphox_profundo():
    db = Database()

    pd.set_option('display.max_rows', None)
    pd.set_option('display.max_columns', None)
    pd.set_option('display.width', 1000)
    
    query_times = """
    SELECT 
        pt.team_id, 
        t.wins, 
        t.losses
    FROM Pokemon_teams pt
    JOIN Teams t ON pt.team_id = t.id
    JOIN Pokemon_mapping pm ON pt.pokemon_id = pm.pokemon_scraper_id
    JOIN Pokemon_data pd ON pm.pokemon_api_id = pd.id
    WHERE LOWER(pd.name) LIKE '%delphox%';
    """
    
    print("🔮 Conectando ao banco e localizando todos os times com Delphox...")
    with db.connect() as cursor:
        df_times = pd.read_sql_query(query_times, cursor._connection)
        
    if df_times.empty:
        print("❌ Nenhum time encontrado com Delphox nos dados atuais.")
        return

    total_teams = len(df_times)
    total_wins = df_times['wins'].sum()
    total_losses = df_times['losses'].sum()
    total_games = total_wins + total_losses
    winrate_geral = (total_wins / total_games) * 100 if total_games > 0 else 0.0
    
    print(f"✅ Encontrado(s) {total_teams} time(s) centrados na Delphox!")
    print(f"📊 Desempenho Geral da Raposa: {total_games} partidas ({total_wins}V - {total_losses}D) | Winrate: {winrate_geral:.2f}%\n")

    team_ids = df_times['team_id'].tolist()
    
    if len(team_ids) == 1:
        where_clause = f"WHERE pt.team_id = {team_ids[0]}"
    else:
        where_clause = f"WHERE pt.team_id IN {tuple(team_ids)}"

    query_companheiros = f"""
    SELECT 
        pt.team_id,
        pdata.name AS pokemon_name,
        t.wins,
        t.losses
    FROM Pokemon_teams pt
    JOIN Teams t ON pt.team_id = t.id
    JOIN Pokemon_mapping pmap ON pt.pokemon_id = pmap.pokemon_scraper_id
    JOIN Pokemon_data pdata ON pmap.pokemon_api_id = pdata.id
    {where_clause}
      AND LOWER(pdata.name) NOT LIKE '%delphox%';
    """
    
    print("👥 Calculando a sinergia e popularidade dos parceiros de equipe...")
    with db.connect() as cursor:
        df_comps = pd.read_sql_query(query_companheiros, cursor._connection)
        
    if df_comps.empty:
        print("⚠️ Não foram encontrados outros Pokémon registrados com a Delphox.")
        return

    agg_comps = df_comps.groupby('pokemon_name').agg(
        aparicoes=('team_id', 'count'),
        vitorias=('wins', 'sum'),
        derrotas=('losses', 'sum')
    ).reset_index()
    
    agg_comps['Presença nos Times (%)'] = (agg_comps['aparicoes'] / total_teams) * 100
    agg_comps['Winrate do Duo (%)'] = (agg_comps['vitorias'] / (agg_comps['vitorias'] + agg_comps['derrotas'])) * 100
    agg_comps = agg_comps.sort_values(by='Presença nos Times (%)', ascending=False)
    
    print("\n👑 TOP COMPANHEIROS MAIS POPULARES:")
    print(agg_comps[['pokemon_name', 'aparicoes', 'Presença nos Times (%)', 'Winrate do Duo (%)']].head(20).to_string(index=False))

    top_pokemon_alvos = ['Delphox'] + agg_comps['pokemon_name'].head(20).tolist()

    query_builds = f"""
    SELECT 
        pt.id AS pokemon_team_id,
        pdata.name AS pokemon_name,
        i.name AS item_name,
        mdata.name AS move_name,
        mdata.damage_class,
        t.wins,
        t.losses
    FROM Pokemon_moves pm
    JOIN Pokemon_teams pt ON pm.idpokemon_team = pt.id
    JOIN Teams t ON pt.team_id = t.id
    JOIN Pokemon_mapping pmap ON pt.pokemon_id = pmap.pokemon_scraper_id
    JOIN Pokemon_data pdata ON pmap.pokemon_api_id = pdata.id
    JOIN Items i ON pt.item_id = i.id
    JOIN Moves_mapping mm ON pm.idmove = mm.move_scraper_id
    JOIN Moves_data mdata ON mm.move_api_id = mdata.id
    {where_clause};
    """

    print("\n📦 Carregando e mapeando cruzamentos de Itens e Movimentos...")
    with db.connect() as cursor:
        df_builds = pd.read_sql_query(query_builds, cursor._connection)

    output_lines = []

    for poke in top_pokemon_alvos:
        df_poke = df_builds[df_builds['pokemon_name'].str.lower() == poke.lower()]
        if df_poke.empty:
            continue

        output_lines.append("\n" + "=" * 50)
        output_lines.append(f"Nome do pokemon: {poke.upper()}")
        output_lines.append("=" * 50)

        df_unique_pokes = df_poke.drop_duplicates(subset=['pokemon_team_id'])
        total_poke_teams = len(df_unique_pokes)

        df_items_agg = df_unique_pokes.groupby('item_name').agg(
            qtd=('pokemon_team_id', 'count'),
            v_total=('wins', 'sum'),
            d_total=('losses', 'sum')
        ).reset_index()

        df_items_agg['uso_pct'] = (df_items_agg['qtd'] / total_poke_teams) * 100
        df_items_agg['winrate_pct'] = (df_items_agg['v_total'] / (df_items_agg['v_total'] + df_items_agg['d_total'])) * 100
        df_top_items = df_items_agg.sort_values(by='uso_pct', ascending=False).head(5)

        output_lines.append("Lista de itens mais usados:")
        
        for _, item_row in df_top_items.iterrows():
            item_name = item_row['item_name']
            uso = item_row['uso_pct']
            wr = item_row['winrate_pct']
            
            output_lines.append(f"  ↳ Item: {item_name} | Uso: {uso:.2f}% | Winrate: {wr:.2f}%")
            output_lines.append(f"    Movimentos mais usados com {item_name}:")

            df_item_moves = df_poke[df_poke['item_name'] == item_name]
            
            top_moves = df_item_moves['move_name'].value_counts().head(6).reset_index()
            top_moves.columns = ['move_name', 'count']

            for _, move_row in top_moves.iterrows():
                m_name = move_row['move_name']
                m_count = move_row['count']
                m_class = df_item_moves[df_item_moves['move_name'] == m_name]['damage_class'].iloc[0]
                
                output_lines.append(f"      nome: {m_name:<18} | qtd vezes: {m_count:<4} | classe: {m_class}")
            output_lines.append("")

    print("\n".join(output_lines))

analisar_meta_delphox_profundo()
# Out:
# 🔮 Conectando ao banco e localizando todos os times com Delphox...
# ✅ Encontrado(s) 1634 time(s) centrados na Delphox!
# 📊 Desempenho Geral da Raposa: 9180 partidas (4724V - 4456D) | Winrate: 51.46%
#
# 👥 Calculando a sinergia e popularidade dos parceiros de equipe...
#
# 👑 TOP COMPANHEIROS MAIS POPULARES:
#            pokemon_name  aparicoes  Presença nos Times (%)  Winrate do Duo (%)
#                sneasler       1065               65.177479           52.386515
#                garchomp        953               58.323133           52.244596
#               kingambit        832               50.917993           54.730713
#        basculegion-male        491               30.048960           54.679803
#              aerodactyl        436               26.682987           51.472368
#               sinistcha        353               21.603427           50.941423
#         floette-eternal        322               19.706242           54.870666
#              incineroar        300               18.359853           52.121596
#              rotom-wash        293               17.931457           50.959752
#              whimsicott        242               14.810282           47.408964
#                clefable        238               14.565483           52.370690
# maushold-family-of-four        230               14.075887           49.381698
#                 milotic        166               10.159119           46.881497
#                tsareena        129                7.894737           51.595007
#               dragonite        128                7.833537           52.885906
#        aegislash-shield        123                7.527540           53.211009
#               tyranitar        113                6.915545           50.157233
#                 floette        103                6.303550           56.498195
#                vivillon         94                5.752754           54.004107
#         ninetales-alola         84                5.140759           51.441242
#
# 📦 Carregando e mapeando cruzamentos de Itens e Movimentos...
#
# ==================================================
# Nome do pokemon: DELPHOX
# ==================================================
# Lista de itens mais usados:
#   ↳ Item: Delphoxite | Uso: 98.98% | Winrate: 51.47%
#     Movimentos mais usados com Delphoxite:
#       nome: protect            | qtd vezes: 1429 | classe: status
#       nome: heat-wave          | qtd vezes: 1419 | classe: special
#       nome: psychic            | qtd vezes: 1125 | classe: special
#       nome: encore             | qtd vezes: 451  | classe: status
#       nome: substitute         | qtd vezes: 415  | classe: status
#       nome: nasty-plot         | qtd vezes: 311  | classe: status
#
#   ↳ Item: Focus Sash | Uso: 0.34% | Winrate: 33.33%
#     Movimentos mais usados com Focus Sash:
#       nome: psychic            | qtd vezes: 5    | classe: special
#       nome: flamethrower       | qtd vezes: 4    | classe: special
#       nome: fire-blast         | qtd vezes: 3    | classe: special
#       nome: flame-charge       | qtd vezes: 3    | classe: physical
#       nome: protect            | qtd vezes: 2    | classe: status
#       nome: heat-wave          | qtd vezes: 1    | classe: special
#
#   ↳ Item: Leftovers | Uso: 0.20% | Winrate: 21.43%
#     Movimentos mais usados com Leftovers:
#       nome: heat-wave          | qtd vezes: 2    | classe: special
#       nome: protect            | qtd vezes: 2    | classe: status
#       nome: fire-blast         | qtd vezes: 1    | classe: special
#       nome: future-sight       | qtd vezes: 1    | classe: special
#       nome: hyper-voice        | qtd vezes: 1    | classe: special
#       nome: psychic-terrain    | qtd vezes: 1    | classe: status
#
#   ↳ Item: Choice Scarf | Uso: 0.14% | Winrate: 30.00%
#     Movimentos mais usados com Choice Scarf:
#       nome: flamethrower       | qtd vezes: 1    | classe: special
#       nome: trick              | qtd vezes: 1    | classe: status
#       nome: expanding-force    | qtd vezes: 1    | classe: special
#       nome: shadow-ball        | qtd vezes: 1    | classe: special
#       nome: scorching-sands    | qtd vezes: 1    | classe: special
#       nome: heat-wave          | qtd vezes: 1    | classe: special
#
#   ↳ Item: Lum Berry | Uso: 0.14% | Winrate: 36.36%
#     Movimentos mais usados com Lum Berry:
#       nome: protect            | qtd vezes: 2    | classe: status
#       nome: heat-wave          | qtd vezes: 2    | classe: special
#       nome: imprison           | qtd vezes: 1    | classe: status
#       nome: trick-room         | qtd vezes: 1    | classe: status
#       nome: substitute         | qtd vezes: 1    | classe: status
#       nome: psychic            | qtd vezes: 1    | classe: special
#
#
# ==================================================
# Nome do pokemon: SNEASLER
# ==================================================
# Lista de itens mais usados:
#   ↳ Item: White Herb | Uso: 72.77% | Winrate: 52.76%
#     Movimentos mais usados com White Herb:
#       nome: close-combat       | qtd vezes: 774  | classe: physical
#       nome: fake-out           | qtd vezes: 758  | classe: physical
#       nome: dire-claw          | qtd vezes: 753  | classe: physical
#       nome: protect            | qtd vezes: 703  | classe: status
#       nome: coaching           | qtd vezes: 25   | classe: status
#       nome: gunk-shot          | qtd vezes: 20   | classe: physical
#
#   ↳ Item: Focus Sash | Uso: 21.88% | Winrate: 53.89%
#     Movimentos mais usados com Focus Sash:
#       nome: close-combat       | qtd vezes: 233  | classe: physical
#       nome: dire-claw          | qtd vezes: 228  | classe: physical
#       nome: fake-out           | qtd vezes: 227  | classe: physical
#       nome: protect            | qtd vezes: 183  | classe: status
#       nome: coaching           | qtd vezes: 25   | classe: status
#       nome: quick-guard        | qtd vezes: 10   | classe: status
#
#   ↳ Item: Mental Herb | Uso: 2.07% | Winrate: 35.58%
#     Movimentos mais usados com Mental Herb:
#       nome: close-combat       | qtd vezes: 22   | classe: physical
#       nome: dire-claw          | qtd vezes: 22   | classe: physical
#       nome: fake-out           | qtd vezes: 22   | classe: physical
#       nome: protect            | qtd vezes: 16   | classe: status
#       nome: throat-chop        | qtd vezes: 2    | classe: physical
#       nome: rock-slide         | qtd vezes: 2    | classe: physical
#
#   ↳ Item: Sitrus Berry | Uso: 1.78% | Winrate: 47.89%
#     Movimentos mais usados com Sitrus Berry:
#       nome: close-combat       | qtd vezes: 19   | classe: physical
#       nome: dire-claw          | qtd vezes: 19   | classe: physical
#       nome: fake-out           | qtd vezes: 13   | classe: physical
#       nome: rock-tomb          | qtd vezes: 13   | classe: physical
#       nome: protect            | qtd vezes: 9    | classe: status
#       nome: feint              | qtd vezes: 2    | classe: physical
#
#   ↳ Item: Bright Powder | Uso: 0.94% | Winrate: 16.67%
#     Movimentos mais usados com Bright Powder:
#       nome: fake-out           | qtd vezes: 10   | classe: physical
#       nome: dire-claw          | qtd vezes: 10   | classe: physical
#       nome: close-combat       | qtd vezes: 10   | classe: physical
#       nome: u-turn             | qtd vezes: 10   | classe: physical
#
#
# ==================================================
# Nome do pokemon: GARCHOMP
# ==================================================
# Lista de itens mais usados:
#   ↳ Item: Choice Scarf | Uso: 29.59% | Winrate: 53.30%
#     Movimentos mais usados com Choice Scarf:
#       nome: earthquake         | qtd vezes: 277  | classe: physical
#       nome: rock-slide         | qtd vezes: 267  | classe: physical
#       nome: dragon-claw        | qtd vezes: 255  | classe: physical
#       nome: stomping-tantrum   | qtd vezes: 230  | classe: physical
#       nome: breaking-swipe     | qtd vezes: 23   | classe: physical
#       nome: iron-head          | qtd vezes: 21   | classe: physical
#
#   ↳ Item: Soft Sand | Uso: 16.16% | Winrate: 51.80%
#     Movimentos mais usados com Soft Sand:
#       nome: earthquake         | qtd vezes: 153  | classe: physical
#       nome: protect            | qtd vezes: 151  | classe: status
#       nome: rock-slide         | qtd vezes: 112  | classe: physical
#       nome: stomping-tantrum   | qtd vezes: 90   | classe: physical
#       nome: dragon-claw        | qtd vezes: 87   | classe: physical
#       nome: scale-shot         | qtd vezes: 9    | classe: physical
#
#   ↳ Item: White Herb | Uso: 14.48% | Winrate: 52.26%
#     Movimentos mais usados com White Herb:
#       nome: earthquake         | qtd vezes: 135  | classe: physical
#       nome: protect            | qtd vezes: 133  | classe: status
#       nome: dragon-claw        | qtd vezes: 120  | classe: physical
#       nome: rock-slide         | qtd vezes: 115  | classe: physical
#       nome: stomping-tantrum   | qtd vezes: 27   | classe: physical
#       nome: scale-shot         | qtd vezes: 13   | classe: physical
#
#   ↳ Item: Sitrus Berry | Uso: 14.38% | Winrate: 57.71%
#     Movimentos mais usados com Sitrus Berry:
#       nome: earthquake         | qtd vezes: 134  | classe: physical
#       nome: protect            | qtd vezes: 133  | classe: status
#       nome: rock-slide         | qtd vezes: 128  | classe: physical
#       nome: dragon-claw        | qtd vezes: 117  | classe: physical
#       nome: stomping-tantrum   | qtd vezes: 14   | classe: physical
#       nome: scale-shot         | qtd vezes: 9    | classe: physical
#
#   ↳ Item: Lum Berry | Uso: 8.39% | Winrate: 52.04%
#     Movimentos mais usados com Lum Berry:
#       nome: earthquake         | qtd vezes: 78   | classe: physical
#       nome: protect            | qtd vezes: 78   | classe: status
#       nome: rock-slide         | qtd vezes: 71   | classe: physical
#       nome: dragon-claw        | qtd vezes: 69   | classe: physical
#       nome: stomping-tantrum   | qtd vezes: 14   | classe: physical
#       nome: swords-dance       | qtd vezes: 5    | classe: status
#
#
# ==================================================
# Nome do pokemon: KINGAMBIT
# ==================================================
# Lista de itens mais usados:
#   ↳ Item: Black Glasses | Uso: 55.29% | Winrate: 55.20%
#     Movimentos mais usados com Black Glasses:
#       nome: sucker-punch       | qtd vezes: 460  | classe: physical
#       nome: kowtow-cleave      | qtd vezes: 449  | classe: physical
#       nome: protect            | qtd vezes: 441  | classe: status
#       nome: iron-head          | qtd vezes: 212  | classe: physical
#       nome: swords-dance       | qtd vezes: 183  | classe: status
#       nome: low-kick           | qtd vezes: 88   | classe: physical
#
#   ↳ Item: Chople Berry | Uso: 38.58% | Winrate: 54.59%
#     Movimentos mais usados com Chople Berry:
#       nome: sucker-punch       | qtd vezes: 321  | classe: physical
#       nome: protect            | qtd vezes: 305  | classe: status
#       nome: kowtow-cleave      | qtd vezes: 277  | classe: physical
#       nome: iron-head          | qtd vezes: 214  | classe: physical
#       nome: low-kick           | qtd vezes: 135  | classe: physical
#       nome: swords-dance       | qtd vezes: 25   | classe: status
#
#   ↳ Item: Focus Sash | Uso: 3.73% | Winrate: 54.95%
#     Movimentos mais usados com Focus Sash:
#       nome: sucker-punch       | qtd vezes: 30   | classe: physical
#       nome: iron-head          | qtd vezes: 30   | classe: physical
#       nome: protect            | qtd vezes: 25   | classe: status
#       nome: low-kick           | qtd vezes: 19   | classe: physical
#       nome: kowtow-cleave      | qtd vezes: 18   | classe: physical
#       nome: swords-dance       | qtd vezes: 1    | classe: status
#
#   ↳ Item: Occa Berry | Uso: 0.72% | Winrate: 47.73%
#     Movimentos mais usados com Occa Berry:
#       nome: kowtow-cleave      | qtd vezes: 6    | classe: physical
#       nome: sucker-punch       | qtd vezes: 6    | classe: physical
#       nome: iron-head          | qtd vezes: 6    | classe: physical
#       nome: protect            | qtd vezes: 6    | classe: status
#
#   ↳ Item: Quick Claw | Uso: 0.36% | Winrate: 28.57%
#     Movimentos mais usados com Quick Claw:
#       nome: iron-head          | qtd vezes: 2    | classe: physical
#       nome: protect            | qtd vezes: 2    | classe: status
#       nome: sucker-punch       | qtd vezes: 2    | classe: physical
#       nome: kowtow-cleave      | qtd vezes: 2    | classe: physical
#       nome: swords-dance       | qtd vezes: 2    | classe: status
#       nome: low-kick           | qtd vezes: 1    | classe: physical
#
#
# ==================================================
# Nome do pokemon: BASCULEGION-MALE
# ==================================================
# Lista de itens mais usados:
#   ↳ Item: Choice Scarf | Uso: 67.41% | Winrate: 53.58%
#     Movimentos mais usados com Choice Scarf:
#       nome: last-respects      | qtd vezes: 330  | classe: physical
#       nome: wave-crash         | qtd vezes: 327  | classe: physical
#       nome: flip-turn          | qtd vezes: 323  | classe: physical
#       nome: aqua-jet           | qtd vezes: 318  | classe: physical
#       nome: psychic-fangs      | qtd vezes: 6    | classe: physical
#       nome: protect            | qtd vezes: 6    | classe: status
#
#   ↳ Item: Focus Sash | Uso: 22.40% | Winrate: 57.26%
#     Movimentos mais usados com Focus Sash:
#       nome: last-respects      | qtd vezes: 110  | classe: physical
#       nome: aqua-jet           | qtd vezes: 109  | classe: physical
#       nome: protect            | qtd vezes: 108  | classe: status
#       nome: liquidation        | qtd vezes: 97   | classe: physical
#       nome: wave-crash         | qtd vezes: 10   | classe: physical
#       nome: flip-turn          | qtd vezes: 5    | classe: physical
#
#   ↳ Item: Sitrus Berry | Uso: 7.33% | Winrate: 61.06%
#     Movimentos mais usados com Sitrus Berry:
#       nome: wave-crash         | qtd vezes: 36   | classe: physical
#       nome: last-respects      | qtd vezes: 36   | classe: physical
#       nome: aqua-jet           | qtd vezes: 36   | classe: physical
#       nome: protect            | qtd vezes: 36   | classe: status
#
#   ↳ Item: Mystic Water | Uso: 2.44% | Winrate: 42.11%
#     Movimentos mais usados com Mystic Water:
#       nome: wave-crash         | qtd vezes: 12   | classe: physical
#       nome: last-respects      | qtd vezes: 12   | classe: physical
#       nome: protect            | qtd vezes: 11   | classe: status
#       nome: aqua-jet           | qtd vezes: 9    | classe: physical
#       nome: liquidation        | qtd vezes: 3    | classe: physical
#       nome: flip-turn          | qtd vezes: 1    | classe: physical
#
#   ↳ Item: Colbur Berry | Uso: 0.20% | Winrate: 42.86%
#     Movimentos mais usados com Colbur Berry:
#       nome: wave-crash         | qtd vezes: 1    | classe: physical
#       nome: last-respects      | qtd vezes: 1    | classe: physical
#       nome: aqua-jet           | qtd vezes: 1    | classe: physical
#       nome: protect            | qtd vezes: 1    | classe: status
#
#
# ==================================================
# Nome do pokemon: AERODACTYL
# ==================================================
# Lista de itens mais usados:
#   ↳ Item: Focus Sash | Uso: 87.39% | Winrate: 51.40%
#     Movimentos mais usados com Focus Sash:
#       nome: tailwind           | qtd vezes: 379  | classe: status
#       nome: rock-slide         | qtd vezes: 377  | classe: physical
#       nome: dual-wingbeat      | qtd vezes: 353  | classe: physical
#       nome: protect            | qtd vezes: 351  | classe: status
#       nome: wide-guard         | qtd vezes: 39   | classe: status
#       nome: taunt              | qtd vezes: 19   | classe: status
#
#   ↳ Item: Aerodactylite | Uso: 6.65% | Winrate: 52.10%
#     Movimentos mais usados com Aerodactylite:
#       nome: rock-slide         | qtd vezes: 29   | classe: physical
#       nome: tailwind           | qtd vezes: 27   | classe: status
#       nome: protect            | qtd vezes: 26   | classe: status
#       nome: dual-wingbeat      | qtd vezes: 26   | classe: physical
#       nome: wide-guard         | qtd vezes: 4    | classe: status
#       nome: iron-head          | qtd vezes: 2    | classe: physical
#
#   ↳ Item: Lum Berry | Uso: 2.75% | Winrate: 57.65%
#     Movimentos mais usados com Lum Berry:
#       nome: rock-slide         | qtd vezes: 12   | classe: physical
#       nome: tailwind           | qtd vezes: 12   | classe: status
#       nome: dual-wingbeat      | qtd vezes: 11   | classe: physical
#       nome: protect            | qtd vezes: 10   | classe: status
#       nome: wide-guard         | qtd vezes: 2    | classe: status
#       nome: sunny-day          | qtd vezes: 1    | classe: status
#
#   ↳ Item: Hard Stone | Uso: 0.92% | Winrate: 40.00%
#     Movimentos mais usados com Hard Stone:
#       nome: rock-slide         | qtd vezes: 4    | classe: physical
#       nome: tailwind           | qtd vezes: 4    | classe: status
#       nome: protect            | qtd vezes: 4    | classe: status
#       nome: dual-wingbeat      | qtd vezes: 3    | classe: physical
#       nome: wide-guard         | qtd vezes: 1    | classe: status
#
#   ↳ Item: Leftovers | Uso: 0.46% | Winrate: 57.14%
#     Movimentos mais usados com Leftovers:
#       nome: rock-slide         | qtd vezes: 2    | classe: physical
#       nome: dual-wingbeat      | qtd vezes: 2    | classe: physical
#       nome: tailwind           | qtd vezes: 2    | classe: status
#       nome: protect            | qtd vezes: 2    | classe: status
#
#
# ==================================================
# Nome do pokemon: SINISTCHA
# ==================================================
# Lista de itens mais usados:
#   ↳ Item: Sitrus Berry | Uso: 39.09% | Winrate: 50.20%
#     Movimentos mais usados com Sitrus Berry:
#       nome: matcha-gotcha      | qtd vezes: 136  | classe: special
#       nome: rage-powder        | qtd vezes: 134  | classe: status
#       nome: trick-room         | qtd vezes: 96   | classe: status
#       nome: life-dew           | qtd vezes: 66   | classe: status
#       nome: protect            | qtd vezes: 61   | classe: status
#       nome: shadow-ball        | qtd vezes: 31   | classe: special
#
#   ↳ Item: Kasib Berry | Uso: 35.98% | Winrate: 50.40%
#     Movimentos mais usados com Kasib Berry:
#       nome: matcha-gotcha      | qtd vezes: 127  | classe: special
#       nome: rage-powder        | qtd vezes: 127  | classe: status
#       nome: life-dew           | qtd vezes: 105  | classe: status
#       nome: trick-room         | qtd vezes: 73   | classe: status
#       nome: protect            | qtd vezes: 68   | classe: status
#       nome: shadow-ball        | qtd vezes: 5    | classe: special
#
#   ↳ Item: Colbur Berry | Uso: 9.07% | Winrate: 58.49%
#     Movimentos mais usados com Colbur Berry:
#       nome: matcha-gotcha      | qtd vezes: 32   | classe: special
#       nome: rage-powder        | qtd vezes: 32   | classe: status
#       nome: trick-room         | qtd vezes: 21   | classe: status
#       nome: protect            | qtd vezes: 17   | classe: status
#       nome: life-dew           | qtd vezes: 14   | classe: status
#       nome: strength-sap       | qtd vezes: 8    | classe: status
#
#   ↳ Item: Leftovers | Uso: 6.80% | Winrate: 55.73%
#     Movimentos mais usados com Leftovers:
#       nome: matcha-gotcha      | qtd vezes: 24   | classe: special
#       nome: rage-powder        | qtd vezes: 23   | classe: status
#       nome: life-dew           | qtd vezes: 17   | classe: status
#       nome: protect            | qtd vezes: 12   | classe: status
#       nome: trick-room         | qtd vezes: 10   | classe: status
#       nome: strength-sap       | qtd vezes: 6    | classe: status
#
#   ↳ Item: Occa Berry | Uso: 4.82% | Winrate: 45.92%
#     Movimentos mais usados com Occa Berry:
#       nome: matcha-gotcha      | qtd vezes: 17   | classe: special
#       nome: rage-powder        | qtd vezes: 16   | classe: status
#       nome: trick-room         | qtd vezes: 16   | classe: status
#       nome: life-dew           | qtd vezes: 10   | classe: status
#       nome: protect            | qtd vezes: 3    | classe: status
#       nome: strength-sap       | qtd vezes: 3    | classe: status
#
#
# ==================================================
# Nome do pokemon: FLOETTE-ETERNAL
# ==================================================
# Lista de itens mais usados:
#   ↳ Item: Floettite | Uso: 100.00% | Winrate: 54.87%
#     Movimentos mais usados com Floettite:
#       nome: protect            | qtd vezes: 321  | classe: status
#       nome: dazzling-gleam     | qtd vezes: 278  | classe: special
#       nome: moonblast          | qtd vezes: 237  | classe: special
#       nome: calm-mind          | qtd vezes: 227  | classe: status
#       nome: draining-kiss      | qtd vezes: 127  | classe: special
#       nome: light-of-ruin      | qtd vezes: 91   | classe: special
#
#
# ==================================================
# Nome do pokemon: INCINEROAR
# ==================================================
# Lista de itens mais usados:
#   ↳ Item: Sitrus Berry | Uso: 57.67% | Winrate: 53.03%
#     Movimentos mais usados com Sitrus Berry:
#       nome: fake-out           | qtd vezes: 171  | classe: physical
#       nome: flare-blitz        | qtd vezes: 169  | classe: physical
#       nome: parting-shot       | qtd vezes: 169  | classe: status
#       nome: throat-chop        | qtd vezes: 111  | classe: physical
#       nome: darkest-lariat     | qtd vezes: 41   | classe: physical
#       nome: helping-hand       | qtd vezes: 13   | classe: status
#
#   ↳ Item: Passho Berry | Uso: 17.00% | Winrate: 48.29%
#     Movimentos mais usados com Passho Berry:
#       nome: flare-blitz        | qtd vezes: 51   | classe: physical
#       nome: parting-shot       | qtd vezes: 51   | classe: status
#       nome: fake-out           | qtd vezes: 51   | classe: physical
#       nome: throat-chop        | qtd vezes: 45   | classe: physical
#       nome: darkest-lariat     | qtd vezes: 3    | classe: physical
#       nome: helping-hand       | qtd vezes: 1    | classe: status
#
#   ↳ Item: Leftovers | Uso: 11.33% | Winrate: 56.28%
#     Movimentos mais usados com Leftovers:
#       nome: parting-shot       | qtd vezes: 34   | classe: status
#       nome: fake-out           | qtd vezes: 34   | classe: physical
#       nome: flare-blitz        | qtd vezes: 31   | classe: physical
#       nome: throat-chop        | qtd vezes: 29   | classe: physical
#       nome: helping-hand       | qtd vezes: 4    | classe: status
#       nome: taunt              | qtd vezes: 2    | classe: status
#
#   ↳ Item: Chople Berry | Uso: 6.67% | Winrate: 51.06%
#     Movimentos mais usados com Chople Berry:
#       nome: fake-out           | qtd vezes: 20   | classe: physical
#       nome: parting-shot       | qtd vezes: 19   | classe: status
#       nome: flare-blitz        | qtd vezes: 16   | classe: physical
#       nome: throat-chop        | qtd vezes: 8    | classe: physical
#       nome: darkest-lariat     | qtd vezes: 6    | classe: physical
#       nome: will-o-wisp        | qtd vezes: 4    | classe: status
#
#   ↳ Item: Shuca Berry | Uso: 3.33% | Winrate: 50.00%
#     Movimentos mais usados com Shuca Berry:
#       nome: fake-out           | qtd vezes: 10   | classe: physical
#       nome: parting-shot       | qtd vezes: 9    | classe: status
#       nome: flare-blitz        | qtd vezes: 8    | classe: physical
#       nome: darkest-lariat     | qtd vezes: 4    | classe: physical
#       nome: will-o-wisp        | qtd vezes: 3    | classe: status
#       nome: throat-chop        | qtd vezes: 2    | classe: physical
#
#
# ==================================================
# Nome do pokemon: ROTOM-WASH
# ==================================================
# Lista de itens mais usados:
#   ↳ Item: Sitrus Berry | Uso: 35.49% | Winrate: 50.92%
#     Movimentos mais usados com Sitrus Berry:
#       nome: hydro-pump         | qtd vezes: 103  | classe: special
#       nome: will-o-wisp        | qtd vezes: 81   | classe: status
#       nome: thunderbolt        | qtd vezes: 79   | classe: special
#       nome: protect            | qtd vezes: 69   | classe: status
#       nome: volt-switch        | qtd vezes: 47   | classe: special
#       nome: electroweb         | qtd vezes: 21   | classe: special
#
#   ↳ Item: Choice Scarf | Uso: 32.76% | Winrate: 52.85%
#     Movimentos mais usados com Choice Scarf:
#       nome: hydro-pump         | qtd vezes: 96   | classe: special
#       nome: volt-switch        | qtd vezes: 83   | classe: special
#       nome: electroweb         | qtd vezes: 80   | classe: special
#       nome: thunderbolt        | qtd vezes: 63   | classe: special
#       nome: will-o-wisp        | qtd vezes: 32   | classe: status
#       nome: trick              | qtd vezes: 19   | classe: status
#
#   ↳ Item: Leftovers | Uso: 25.94% | Winrate: 50.50%
#     Movimentos mais usados com Leftovers:
#       nome: hydro-pump         | qtd vezes: 76   | classe: special
#       nome: thunderbolt        | qtd vezes: 58   | classe: special
#       nome: will-o-wisp        | qtd vezes: 56   | classe: status
#       nome: protect            | qtd vezes: 55   | classe: status
#       nome: volt-switch        | qtd vezes: 27   | classe: special
#       nome: electroweb         | qtd vezes: 13   | classe: special
#
#   ↳ Item: Magnet | Uso: 4.44% | Winrate: 42.86%
#     Movimentos mais usados com Magnet:
#       nome: hydro-pump         | qtd vezes: 13   | classe: special
#       nome: thunderbolt        | qtd vezes: 9    | classe: special
#       nome: protect            | qtd vezes: 9    | classe: status
#       nome: electroweb         | qtd vezes: 7    | classe: special
#       nome: volt-switch        | qtd vezes: 7    | classe: special
#       nome: will-o-wisp        | qtd vezes: 4    | classe: status
#
#   ↳ Item: Rindo Berry | Uso: 0.68% | Winrate: 41.18%
#     Movimentos mais usados com Rindo Berry:
#       nome: protect            | qtd vezes: 2    | classe: status
#       nome: hydro-pump         | qtd vezes: 2    | classe: special
#       nome: electroweb         | qtd vezes: 2    | classe: special
#       nome: thunderbolt        | qtd vezes: 1    | classe: special
#       nome: volt-switch        | qtd vezes: 1    | classe: special
#
#
# ==================================================
# Nome do pokemon: WHIMSICOTT
# ==================================================
# Lista de itens mais usados:
#   ↳ Item: Focus Sash | Uso: 74.79% | Winrate: 46.97%
#     Movimentos mais usados com Focus Sash:
#       nome: tailwind           | qtd vezes: 181  | classe: status
#       nome: moonblast          | qtd vezes: 168  | classe: special
#       nome: encore             | qtd vezes: 116  | classe: status
#       nome: protect            | qtd vezes: 89   | classe: status
#       nome: sunny-day          | qtd vezes: 84   | classe: status
#       nome: energy-ball        | qtd vezes: 19   | classe: special
#
#   ↳ Item: Mental Herb | Uso: 11.98% | Winrate: 46.60%
#     Movimentos mais usados com Mental Herb:
#       nome: tailwind           | qtd vezes: 29   | classe: status
#       nome: moonblast          | qtd vezes: 27   | classe: special
#       nome: encore             | qtd vezes: 17   | classe: status
#       nome: protect            | qtd vezes: 17   | classe: status
#       nome: sunny-day          | qtd vezes: 11   | classe: status
#       nome: taunt              | qtd vezes: 7    | classe: status
#
#   ↳ Item: Fairy Feather | Uso: 3.31% | Winrate: 44.19%
#     Movimentos mais usados com Fairy Feather:
#       nome: tailwind           | qtd vezes: 8    | classe: status
#       nome: moonblast          | qtd vezes: 7    | classe: special
#       nome: encore             | qtd vezes: 5    | classe: status
#       nome: protect            | qtd vezes: 4    | classe: status
#       nome: sunny-day          | qtd vezes: 3    | classe: status
#       nome: taunt              | qtd vezes: 2    | classe: status
#
#   ↳ Item: Occa Berry | Uso: 2.48% | Winrate: 50.00%
#     Movimentos mais usados com Occa Berry:
#       nome: moonblast          | qtd vezes: 6    | classe: special
#       nome: tailwind           | qtd vezes: 6    | classe: status
#       nome: encore             | qtd vezes: 5    | classe: status
#       nome: helping-hand       | qtd vezes: 2    | classe: status
#       nome: protect            | qtd vezes: 2    | classe: status
#       nome: fake-tears         | qtd vezes: 2    | classe: status
#
#   ↳ Item: Bright Powder | Uso: 1.65% | Winrate: 47.62%
#     Movimentos mais usados com Bright Powder:
#       nome: tailwind           | qtd vezes: 4    | classe: status
#       nome: moonblast          | qtd vezes: 4    | classe: special
#       nome: sunny-day          | qtd vezes: 3    | classe: status
#       nome: encore             | qtd vezes: 2    | classe: status
#       nome: protect            | qtd vezes: 2    | classe: status
#       nome: helping-hand       | qtd vezes: 1    | classe: status
#
#
# ==================================================
# Nome do pokemon: CLEFABLE
# ==================================================
# Lista de itens mais usados:
#   ↳ Item: Sitrus Berry | Uso: 85.71% | Winrate: 53.50%
#     Movimentos mais usados com Sitrus Berry:
#       nome: follow-me          | qtd vezes: 203  | classe: status
#       nome: moonblast          | qtd vezes: 200  | classe: special
#       nome: protect            | qtd vezes: 198  | classe: status
#       nome: helping-hand       | qtd vezes: 164  | classe: status
#       nome: icy-wind           | qtd vezes: 24   | classe: special
#       nome: life-dew           | qtd vezes: 17   | classe: status
#
#   ↳ Item: Leftovers | Uso: 4.20% | Winrate: 53.03%
#     Movimentos mais usados com Leftovers:
#       nome: follow-me          | qtd vezes: 10   | classe: status
#       nome: moonblast          | qtd vezes: 10   | classe: special
#       nome: protect            | qtd vezes: 8    | classe: status
#       nome: helping-hand       | qtd vezes: 5    | classe: status
#       nome: icy-wind           | qtd vezes: 2    | classe: special
#       nome: life-dew           | qtd vezes: 2    | classe: status
#
#   ↳ Item: Mental Herb | Uso: 2.52% | Winrate: 51.52%
#     Movimentos mais usados com Mental Herb:
#       nome: follow-me          | qtd vezes: 6    | classe: status
#       nome: helping-hand       | qtd vezes: 6    | classe: status
#       nome: moonblast          | qtd vezes: 5    | classe: special
#       nome: protect            | qtd vezes: 3    | classe: status
#       nome: life-dew           | qtd vezes: 3    | classe: status
#       nome: alluring-voice     | qtd vezes: 1    | classe: special
#
#   ↳ Item: Clefablite | Uso: 2.52% | Winrate: 42.50%
#     Movimentos mais usados com Clefablite:
#       nome: moonblast          | qtd vezes: 5    | classe: special
#       nome: protect            | qtd vezes: 4    | classe: status
#       nome: moonlight          | qtd vezes: 2    | classe: status
#       nome: calm-mind          | qtd vezes: 2    | classe: status
#       nome: follow-me          | qtd vezes: 2    | classe: status
#       nome: flamethrower       | qtd vezes: 1    | classe: special
#
#   ↳ Item: Bright Powder | Uso: 2.52% | Winrate: 23.81%
#     Movimentos mais usados com Bright Powder:
#       nome: protect            | qtd vezes: 6    | classe: status
#       nome: follow-me          | qtd vezes: 6    | classe: status
#       nome: helping-hand       | qtd vezes: 6    | classe: status
#       nome: life-dew           | qtd vezes: 6    | classe: status
#
#
# ==================================================
# Nome do pokemon: MAUSHOLD-FAMILY-OF-FOUR
# ==================================================
# Lista de itens mais usados:
#   ↳ Item: Chople Berry | Uso: 75.22% | Winrate: 50.49%
#     Movimentos mais usados com Chople Berry:
#       nome: follow-me          | qtd vezes: 173  | classe: status
#       nome: protect            | qtd vezes: 170  | classe: status
#       nome: super-fang         | qtd vezes: 163  | classe: physical
#       nome: taunt              | qtd vezes: 74   | classe: status
#       nome: feint              | qtd vezes: 66   | classe: physical
#       nome: helping-hand       | qtd vezes: 30   | classe: status
#
#   ↳ Item: Focus Sash | Uso: 12.61% | Winrate: 45.04%
#     Movimentos mais usados com Focus Sash:
#       nome: follow-me          | qtd vezes: 29   | classe: status
#       nome: super-fang         | qtd vezes: 27   | classe: physical
#       nome: protect            | qtd vezes: 23   | classe: status
#       nome: feint              | qtd vezes: 13   | classe: physical
#       nome: taunt              | qtd vezes: 12   | classe: status
#       nome: encore             | qtd vezes: 5    | classe: status
#
#   ↳ Item: Sitrus Berry | Uso: 9.57% | Winrate: 48.00%
#     Movimentos mais usados com Sitrus Berry:
#       nome: follow-me          | qtd vezes: 22   | classe: status
#       nome: protect            | qtd vezes: 20   | classe: status
#       nome: taunt              | qtd vezes: 17   | classe: status
#       nome: super-fang         | qtd vezes: 11   | classe: physical
#       nome: baby-doll-eyes     | qtd vezes: 10   | classe: status
#       nome: encore             | qtd vezes: 4    | classe: status
#
#   ↳ Item: Bright Powder | Uso: 0.87% | Winrate: 0.00%
#     Movimentos mais usados com Bright Powder:
#       nome: population-bomb    | qtd vezes: 2    | classe: physical
#       nome: feint              | qtd vezes: 2    | classe: physical
#       nome: helping-hand       | qtd vezes: 2    | classe: status
#       nome: follow-me          | qtd vezes: 2    | classe: status
#
#   ↳ Item: Kings Rock | Uso: 0.87% | Winrate: 42.86%
#     Movimentos mais usados com Kings Rock:
#       nome: taunt              | qtd vezes: 2    | classe: status
#       nome: follow-me          | qtd vezes: 2    | classe: status
#       nome: protect            | qtd vezes: 2    | classe: status
#       nome: population-bomb    | qtd vezes: 2    | classe: physical
#
#
# ==================================================
# Nome do pokemon: MILOTIC
# ==================================================
# Lista de itens mais usados:
#   ↳ Item: Leftovers | Uso: 80.72% | Winrate: 47.27%
#     Movimentos mais usados com Leftovers:
#       nome: scald              | qtd vezes: 105  | classe: special
#       nome: protect            | qtd vezes: 102  | classe: status
#       nome: icy-wind           | qtd vezes: 81   | classe: special
#       nome: recover            | qtd vezes: 57   | classe: status
#       nome: ice-beam           | qtd vezes: 52   | classe: special
#       nome: coil               | qtd vezes: 32   | classe: status
#
#   ↳ Item: Sitrus Berry | Uso: 12.65% | Winrate: 44.37%
#     Movimentos mais usados com Sitrus Berry:
#       nome: scald              | qtd vezes: 16   | classe: special
#       nome: protect            | qtd vezes: 16   | classe: status
#       nome: ice-beam           | qtd vezes: 11   | classe: special
#       nome: recover            | qtd vezes: 11   | classe: status
#       nome: icy-wind           | qtd vezes: 11   | classe: special
#       nome: helping-hand       | qtd vezes: 6    | classe: status
#
#   ↳ Item: Mystic Water | Uso: 5.42% | Winrate: 48.78%
#     Movimentos mais usados com Mystic Water:
#       nome: scald              | qtd vezes: 9    | classe: special
#       nome: ice-beam           | qtd vezes: 9    | classe: special
#       nome: protect            | qtd vezes: 8    | classe: status
#       nome: icy-wind           | qtd vezes: 8    | classe: special
#       nome: muddy-water        | qtd vezes: 1    | classe: special
#       nome: recover            | qtd vezes: 1    | classe: status
#
#   ↳ Item: Choice Scarf | Uso: 0.60% | Winrate: 0.00%
#     Movimentos mais usados com Choice Scarf:
#       nome: scald              | qtd vezes: 1    | classe: special
#       nome: muddy-water        | qtd vezes: 1    | classe: special
#       nome: icy-wind           | qtd vezes: 1    | classe: special
#       nome: ice-beam           | qtd vezes: 1    | classe: special
#
#   ↳ Item: Rindo Berry | Uso: 0.60% | Winrate: 50.00%
#     Movimentos mais usados com Rindo Berry:
#       nome: icy-wind           | qtd vezes: 1    | classe: special
#       nome: hydro-pump         | qtd vezes: 1    | classe: special
#       nome: protect            | qtd vezes: 1    | classe: status
#       nome: ice-beam           | qtd vezes: 1    | classe: special
#
#
# ==================================================
# Nome do pokemon: TSAREENA
# ==================================================
# Lista de itens mais usados:
#   ↳ Item: Sitrus Berry | Uso: 57.36% | Winrate: 50.51%
#     Movimentos mais usados com Sitrus Berry:
#       nome: triple-axel        | qtd vezes: 68   | classe: physical
#       nome: trop-kick          | qtd vezes: 62   | classe: physical
#       nome: low-kick           | qtd vezes: 60   | classe: physical
#       nome: protect            | qtd vezes: 44   | classe: status
#       nome: sunny-day          | qtd vezes: 22   | classe: status
#       nome: helping-hand       | qtd vezes: 14   | classe: status
#
#   ↳ Item: Choice Scarf | Uso: 16.28% | Winrate: 56.85%
#     Movimentos mais usados com Choice Scarf:
#       nome: triple-axel        | qtd vezes: 19   | classe: physical
#       nome: low-kick           | qtd vezes: 19   | classe: physical
#       nome: u-turn             | qtd vezes: 16   | classe: physical
#       nome: power-whip         | qtd vezes: 15   | classe: physical
#       nome: trop-kick          | qtd vezes: 6    | classe: physical
#       nome: knock-off          | qtd vezes: 5    | classe: physical
#
#   ↳ Item: Miracle Seed | Uso: 8.53% | Winrate: 50.00%
#     Movimentos mais usados com Miracle Seed:
#       nome: protect            | qtd vezes: 10   | classe: status
#       nome: triple-axel        | qtd vezes: 10   | classe: physical
#       nome: trop-kick          | qtd vezes: 8    | classe: physical
#       nome: low-kick           | qtd vezes: 7    | classe: physical
#       nome: power-whip         | qtd vezes: 3    | classe: physical
#       nome: knock-off          | qtd vezes: 2    | classe: physical
#
#   ↳ Item: Occa Berry | Uso: 6.20% | Winrate: 50.00%
#     Movimentos mais usados com Occa Berry:
#       nome: low-kick           | qtd vezes: 7    | classe: physical
#       nome: trop-kick          | qtd vezes: 6    | classe: physical
#       nome: triple-axel        | qtd vezes: 6    | classe: physical
#       nome: taunt              | qtd vezes: 5    | classe: status
#       nome: protect            | qtd vezes: 4    | classe: status
#       nome: power-whip         | qtd vezes: 2    | classe: physical
#
#   ↳ Item: Focus Sash | Uso: 3.10% | Winrate: 57.69%
#     Movimentos mais usados com Focus Sash:
#       nome: trop-kick          | qtd vezes: 4    | classe: physical
#       nome: triple-axel        | qtd vezes: 4    | classe: physical
#       nome: protect            | qtd vezes: 4    | classe: status
#       nome: low-kick           | qtd vezes: 3    | classe: physical
#       nome: taunt              | qtd vezes: 1    | classe: status
#
#
# ==================================================
# Nome do pokemon: DRAGONITE
# ==================================================
# Lista de itens mais usados:
#   ↳ Item: Lum Berry | Uso: 72.66% | Winrate: 54.79%
#     Movimentos mais usados com Lum Berry:
#       nome: extreme-speed      | qtd vezes: 88   | classe: physical
#       nome: protect            | qtd vezes: 87   | classe: status
#       nome: scale-shot         | qtd vezes: 83   | classe: physical
#       nome: haze               | qtd vezes: 52   | classe: status
#       nome: tailwind           | qtd vezes: 27   | classe: status
#       nome: low-kick           | qtd vezes: 11   | classe: physical
#
#   ↳ Item: Dragoninite | Uso: 11.72% | Winrate: 44.83%
#     Movimentos mais usados com Dragoninite:
#       nome: protect            | qtd vezes: 9    | classe: status
#       nome: hurricane          | qtd vezes: 9    | classe: special
#       nome: extreme-speed      | qtd vezes: 8    | classe: physical
#       nome: dragon-pulse       | qtd vezes: 8    | classe: special
#       nome: draco-meteor       | qtd vezes: 6    | classe: special
#       nome: thunderbolt        | qtd vezes: 5    | classe: special
#
#   ↳ Item: Dragon Fang | Uso: 6.25% | Winrate: 60.00%
#     Movimentos mais usados com Dragon Fang:
#       nome: extreme-speed      | qtd vezes: 8    | classe: physical
#       nome: protect            | qtd vezes: 6    | classe: status
#       nome: dragon-claw        | qtd vezes: 6    | classe: physical
#       nome: low-kick           | qtd vezes: 5    | classe: physical
#       nome: tailwind           | qtd vezes: 3    | classe: status
#       nome: scale-shot         | qtd vezes: 2    | classe: physical
#
#   ↳ Item: Leftovers | Uso: 2.34% | Winrate: 21.43%
#     Movimentos mais usados com Leftovers:
#       nome: aerial-ace         | qtd vezes: 1    | classe: physical
#       nome: tailwind           | qtd vezes: 1    | classe: status
#       nome: dragon-claw        | qtd vezes: 1    | classe: physical
#       nome: extreme-speed      | qtd vezes: 1    | classe: physical
#       nome: hurricane          | qtd vezes: 1    | classe: special
#       nome: fire-blast         | qtd vezes: 1    | classe: special
#
#   ↳ Item: Choice Scarf | Uso: 0.78% | Winrate: 50.00%
#     Movimentos mais usados com Choice Scarf:
#       nome: breaking-swipe     | qtd vezes: 1    | classe: physical
#       nome: earthquake         | qtd vezes: 1    | classe: physical
#       nome: rock-slide         | qtd vezes: 1    | classe: physical
#       nome: icy-wind           | qtd vezes: 1    | classe: special
#
#
# ==================================================
# Nome do pokemon: AEGISLASH-SHIELD
# ==================================================
# Lista de itens mais usados:
#   ↳ Item: Spell Tag | Uso: 79.67% | Winrate: 55.87%
#     Movimentos mais usados com Spell Tag:
#       nome: shadow-sneak       | qtd vezes: 95   | classe: physical
#       nome: kings-shield       | qtd vezes: 89   | classe: status
#       nome: poltergeist        | qtd vezes: 86   | classe: physical
#       nome: sacred-sword       | qtd vezes: 35   | classe: physical
#       nome: iron-head          | qtd vezes: 30   | classe: physical
#       nome: close-combat       | qtd vezes: 23   | classe: physical
#
#   ↳ Item: Leftovers | Uso: 6.50% | Winrate: 50.00%
#     Movimentos mais usados com Leftovers:
#       nome: kings-shield       | qtd vezes: 7    | classe: status
#       nome: iron-head          | qtd vezes: 4    | classe: physical
#       nome: shadow-ball        | qtd vezes: 4    | classe: special
#       nome: poltergeist        | qtd vezes: 3    | classe: physical
#       nome: shadow-sneak       | qtd vezes: 3    | classe: physical
#       nome: wide-guard         | qtd vezes: 3    | classe: status
#
#   ↳ Item: Focus Sash | Uso: 4.88% | Winrate: 34.62%
#     Movimentos mais usados com Focus Sash:
#       nome: kings-shield       | qtd vezes: 6    | classe: status
#       nome: poltergeist        | qtd vezes: 5    | classe: physical
#       nome: sacred-sword       | qtd vezes: 4    | classe: physical
#       nome: shadow-sneak       | qtd vezes: 3    | classe: physical
#       nome: wide-guard         | qtd vezes: 3    | classe: status
#       nome: protect            | qtd vezes: 1    | classe: status
#
#   ↳ Item: Metal Coat | Uso: 3.25% | Winrate: 40.00%
#     Movimentos mais usados com Metal Coat:
#       nome: kings-shield       | qtd vezes: 4    | classe: status
#       nome: wide-guard         | qtd vezes: 3    | classe: status
#       nome: flash-cannon       | qtd vezes: 2    | classe: special
#       nome: shadow-ball        | qtd vezes: 2    | classe: special
#       nome: shadow-sneak       | qtd vezes: 2    | classe: physical
#       nome: iron-head          | qtd vezes: 2    | classe: physical
#
#   ↳ Item: Colbur Berry | Uso: 1.63% | Winrate: 37.50%
#     Movimentos mais usados com Colbur Berry:
#       nome: poltergeist        | qtd vezes: 2    | classe: physical
#       nome: close-combat       | qtd vezes: 2    | classe: physical
#       nome: kings-shield       | qtd vezes: 2    | classe: status
#       nome: shadow-sneak       | qtd vezes: 1    | classe: physical
#       nome: iron-head          | qtd vezes: 1    | classe: physical
#
#
# ==================================================
# Nome do pokemon: TYRANITAR
# ==================================================
# Lista de itens mais usados:
#   ↳ Item: Tyranitarite | Uso: 74.34% | Winrate: 51.31%
#     Movimentos mais usados com Tyranitarite:
#       nome: rock-slide         | qtd vezes: 83   | classe: physical
#       nome: protect            | qtd vezes: 81   | classe: status
#       nome: knock-off          | qtd vezes: 69   | classe: physical
#       nome: low-kick           | qtd vezes: 52   | classe: physical
#       nome: crunch             | qtd vezes: 12   | classe: physical
#       nome: dragon-dance       | qtd vezes: 11   | classe: status
#
#   ↳ Item: Chople Berry | Uso: 10.62% | Winrate: 39.34%
#     Movimentos mais usados com Chople Berry:
#       nome: rock-slide         | qtd vezes: 12   | classe: physical
#       nome: knock-off          | qtd vezes: 12   | classe: physical
#       nome: protect            | qtd vezes: 12   | classe: status
#       nome: low-kick           | qtd vezes: 6    | classe: physical
#       nome: ice-punch          | qtd vezes: 2    | classe: physical
#       nome: thunder-punch      | qtd vezes: 1    | classe: physical
#
#   ↳ Item: Choice Scarf | Uso: 6.19% | Winrate: 48.84%
#     Movimentos mais usados com Choice Scarf:
#       nome: rock-slide         | qtd vezes: 7    | classe: physical
#       nome: knock-off          | qtd vezes: 6    | classe: physical
#       nome: low-kick           | qtd vezes: 6    | classe: physical
#       nome: ice-punch          | qtd vezes: 4    | classe: physical
#       nome: superpower         | qtd vezes: 1    | classe: physical
#       nome: thunder-punch      | qtd vezes: 1    | classe: physical
#
#   ↳ Item: Focus Sash | Uso: 3.54% | Winrate: 37.04%
#     Movimentos mais usados com Focus Sash:
#       nome: protect            | qtd vezes: 4    | classe: status
#       nome: rock-slide         | qtd vezes: 3    | classe: physical
#       nome: knock-off          | qtd vezes: 3    | classe: physical
#       nome: low-kick           | qtd vezes: 2    | classe: physical
#       nome: breaking-swipe     | qtd vezes: 1    | classe: physical
#       nome: rock-blast         | qtd vezes: 1    | classe: physical
#
#   ↳ Item: Lum Berry | Uso: 2.65% | Winrate: 67.74%
#     Movimentos mais usados com Lum Berry:
#       nome: protect            | qtd vezes: 3    | classe: status
#       nome: rock-slide         | qtd vezes: 3    | classe: physical
#       nome: knock-off          | qtd vezes: 3    | classe: physical
#       nome: low-kick           | qtd vezes: 3    | classe: physical
#
#
# ==================================================
# Nome do pokemon: FLOETTE
# ==================================================
# Lista de itens mais usados:
#   ↳ Item: Floettite | Uso: 98.06% | Winrate: 56.30%
#     Movimentos mais usados com Floettite:
#       nome: protect            | qtd vezes: 100  | classe: status
#       nome: dazzling-gleam     | qtd vezes: 96   | classe: special
#       nome: moonblast          | qtd vezes: 83   | classe: special
#       nome: calm-mind          | qtd vezes: 63   | classe: status
#       nome: light-of-ruin      | qtd vezes: 38   | classe: special
#       nome: draining-kiss      | qtd vezes: 21   | classe: special
#
#   ↳ Item: Floetitte | Uso: 1.94% | Winrate: 64.29%
#     Movimentos mais usados com Floetitte:
#       nome: protect            | qtd vezes: 2    | classe: status
#       nome: moonblast          | qtd vezes: 2    | classe: special
#       nome: dazzling-gleam     | qtd vezes: 2    | classe: special
#       nome: calm-mind          | qtd vezes: 2    | classe: status
#
#
# ==================================================
# Nome do pokemon: VIVILLON
# ==================================================
# Lista de itens mais usados:
#   ↳ Item: Focus Sash | Uso: 51.06% | Winrate: 60.00%
#     Movimentos mais usados com Focus Sash:
#       nome: sleep-powder       | qtd vezes: 48   | classe: status
#       nome: protect            | qtd vezes: 44   | classe: status
#       nome: rage-powder        | qtd vezes: 43   | classe: status
#       nome: hurricane          | qtd vezes: 37   | classe: special
#       nome: pollen-puff        | qtd vezes: 12   | classe: special
#       nome: tailwind           | qtd vezes: 6    | classe: status
#
#   ↳ Item: Choice Scarf | Uso: 48.94% | Winrate: 46.23%
#     Movimentos mais usados com Choice Scarf:
#       nome: sleep-powder       | qtd vezes: 46   | classe: status
#       nome: rage-powder        | qtd vezes: 46   | classe: status
#       nome: hurricane          | qtd vezes: 44   | classe: special
#       nome: tailwind           | qtd vezes: 33   | classe: status
#       nome: pollen-puff        | qtd vezes: 15   | classe: special
#
#
# ==================================================
# Nome do pokemon: NINETALES-ALOLA
# ==================================================
# Lista de itens mais usados:
#   ↳ Item: Focus Sash | Uso: 35.71% | Winrate: 49.03%
#     Movimentos mais usados com Focus Sash:
#       nome: blizzard           | qtd vezes: 29   | classe: special
#       nome: protect            | qtd vezes: 29   | classe: status
#       nome: freeze-dry         | qtd vezes: 20   | classe: special
#       nome: aurora-veil        | qtd vezes: 19   | classe: status
#       nome: encore             | qtd vezes: 12   | classe: status
#       nome: moonblast          | qtd vezes: 5    | classe: special
#
#   ↳ Item: Choice Scarf | Uso: 29.76% | Winrate: 58.57%
#     Movimentos mais usados com Choice Scarf:
#       nome: icy-wind           | qtd vezes: 25   | classe: special
#       nome: blizzard           | qtd vezes: 25   | classe: special
#       nome: freeze-dry         | qtd vezes: 24   | classe: special
#       nome: moonblast          | qtd vezes: 22   | classe: special
#       nome: fake-tears         | qtd vezes: 3    | classe: status
#       nome: disable            | qtd vezes: 1    | classe: status
#
#   ↳ Item: Never-Melt Ice | Uso: 16.67% | Winrate: 52.31%
#     Movimentos mais usados com Never-Melt Ice:
#       nome: blizzard           | qtd vezes: 14   | classe: special
#       nome: aurora-veil        | qtd vezes: 11   | classe: status
#       nome: protect            | qtd vezes: 10   | classe: status
#       nome: moonblast          | qtd vezes: 7    | classe: special
#       nome: freeze-dry         | qtd vezes: 6    | classe: special
#       nome: icy-wind           | qtd vezes: 6    | classe: special
#
#   ↳ Item: Occa Berry | Uso: 10.71% | Winrate: 44.00%
#     Movimentos mais usados com Occa Berry:
#       nome: aurora-veil        | qtd vezes: 9    | classe: status
#       nome: blizzard           | qtd vezes: 9    | classe: special
#       nome: encore             | qtd vezes: 7    | classe: status
#       nome: moonblast          | qtd vezes: 5    | classe: special
#       nome: icy-wind           | qtd vezes: 3    | classe: special
#       nome: freeze-dry         | qtd vezes: 1    | classe: special
#
#   ↳ Item: Fairy Feather | Uso: 2.38% | Winrate: 38.46%
#     Movimentos mais usados com Fairy Feather:
#       nome: moonblast          | qtd vezes: 2    | classe: special
#       nome: blizzard           | qtd vezes: 2    | classe: special
#       nome: aurora-veil        | qtd vezes: 2    | classe: status
#       nome: helping-hand       | qtd vezes: 1    | classe: status
#       nome: protect            | qtd vezes: 1    | classe: status

# %%
from imports.database import Database
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore", category=UserWarning)

def gerar_grafico_tailwind_delphox():
    db = Database()

    query_base = """
    SELECT 
        pt.team_id,
        t.wins,
        t.losses,
        mdata.name AS move_name
    FROM Pokemon_teams pt
    JOIN Teams t ON pt.team_id = t.id
    JOIN Pokemon_mapping pmap ON pt.pokemon_id = pmap.pokemon_scraper_id
    JOIN Pokemon_data pdata ON pmap.pokemon_api_id = pdata.id
    LEFT JOIN Pokemon_moves pm ON pt.id = pm.idpokemon_team
    LEFT JOIN Moves_mapping mm ON pm.idmove = mm.move_scraper_id
    LEFT JOIN Moves_data mdata ON mm.move_api_id = mdata.id
    WHERE pt.team_id IN (
        SELECT DISTINCT pt2.team_id
        FROM Pokemon_teams pt2
        JOIN Pokemon_mapping pm2 ON pt2.pokemon_id = pm2.pokemon_scraper_id
        JOIN Pokemon_data pd2 ON pm2.pokemon_api_id = pd2.id
        WHERE LOWER(pd2.name) LIKE '%delphox%'
    );
    """
    
    print("🔮 Buscando e cruzando dados de suporte de Tailwind nos times com Delphox...")
    with db.connect() as cursor:
        df = pd.read_sql_query(query_base, cursor._connection)

    if df.empty:
        print("❌ Nenhum dado encontrado para processar.")
        return

    teams_com_tailwind = set(df[df['move_name'].str.lower() == 'tailwind']['team_id'].unique())

    df_teams_unicos = df.drop_duplicates(subset=['team_id']).copy()
    df_teams_unicos['possui_tailwind'] = df_teams_unicos['team_id'].apply(
        lambda x: 'Com Tailwind' if x in teams_com_tailwind else 'Sem Tailwind'
    )

    df_agrupado = df_teams_unicos.groupby('possui_tailwind').agg(
        vitorias=('wins', 'sum'),
        derrotas=('losses', 'sum'),
        qtd_times=('team_id', 'count')
    ).reset_index()

    df_agrupado['winrate'] = (df_agrupado['vitorias'] / (df_agrupado['vitorias'] + df_agrupado['derrotas'])) * 100

    total_v = df_agrupado['vitorias'].sum()
    total_d = df_agrupado['derrotas'].sum()
    media_geral_winrate = (total_v / (total_v + total_d)) * 100

    plt.style.use('dark_background')
    plt.figure(figsize=(10, 7))
    
    sns.set_theme(style="darkgrid", rc={
        "axes.facecolor": "#121212", "figure.facecolor": "#121212",
        "text.color": "white", "axes.labelcolor": "white",
        "xtick.color": "white", "ytick.color": "white"
    })

    cores = ['#2ECC71' if x == 'Com Tailwind' else '#E74C3C' for x in df_agrupado['possui_tailwind']]
    
    ax = sns.barplot(
        x='possui_tailwind', 
        y='winrate', 
        data=df_agrupado, 
        palette=cores, 
        hue='possui_tailwind', 
        legend=False
    )
    
    plt.axhline(media_geral_winrate, color='#F1C40F', linestyle='--', linewidth=1.5, alpha=0.8)
    plt.text(-0.45, media_geral_winrate + 0.5, f"Média Geral: {media_geral_winrate:.2f}%", color='#F1C40F', weight='bold')

    for p in ax.patches:
        height = p.get_height()
        if height > 0:
            tipo = df_agrupado['possui_tailwind'].iloc[int(p.get_x() + 0.5)]
            qtd = df_agrupado[df_agrupado['possui_tailwind'] == tipo]['qtd_times'].iloc[0]
            ax.annotate(f"{height:.2f}%\n({qtd} times)", (p.get_x() + p.get_width() / 2., height / 2),
                        ha='center', va='center', fontsize=11, fontweight='bold', color='white')

    plt.title("Impacto do Controle de Velocidade (Tailwind) no Winrate da Delphox", fontsize=14, weight='bold', pad=15)
    plt.xlabel("Estrutura do Time", weight='bold', fontsize=11)
    plt.ylabel("Winrate Médio Ponderado (%)", weight='bold', fontsize=11)
    plt.ylim(0, 100)

    plt.tight_layout()
    plt.show()

gerar_grafico_tailwind_delphox()
# Out:
# 🔮 Buscando e cruzando dados de suporte de Tailwind nos times com Delphox...

# %%
from imports.database import Database
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore", category=UserWarning)

def gerar_grafico_redirection_delphox():
    db = Database()

    query_base = """
    SELECT 
        pt.team_id,
        t.wins,
        t.losses,
        mdata.name AS move_name
    FROM Pokemon_teams pt
    JOIN Teams t ON pt.team_id = t.id
    JOIN Pokemon_mapping pmap ON pt.pokemon_id = pmap.pokemon_scraper_id
    JOIN Pokemon_data pdata ON pmap.pokemon_api_id = pdata.id
    LEFT JOIN Pokemon_moves pm ON pt.id = pm.idpokemon_team
    LEFT JOIN Moves_mapping mm ON pm.idmove = mm.move_scraper_id
    LEFT JOIN Moves_data mdata ON mm.move_api_id = mdata.id
    WHERE pt.team_id IN (
        SELECT DISTINCT pt2.team_id
        FROM Pokemon_teams pt2
        JOIN Pokemon_mapping pm2 ON pt2.pokemon_id = pm2.pokemon_scraper_id
        JOIN Pokemon_data pd2 ON pm2.pokemon_api_id = pd2.id
        WHERE LOWER(pd2.name) LIKE '%delphox%'
    );
    """
    
    print("🔮 Buscando e cruzando dados de suporte de Redirection nos times com Delphox...")
    with db.connect() as cursor:
        df = pd.read_sql_query(query_base, cursor._connection)

    if df.empty:
        print("❌ Nenhum dado encontrado para processar.")
        return

    df['move_clean'] = df['move_name'].fillna('').str.lower().str.replace('-', ' ').str.strip()

    movimentos_redirection = {'follow me', 'rage powder'}
    teams_com_redirection = set(df[df['move_clean'].isin(movimentos_redirection)]['team_id'].unique())

    df_teams_unicos = df.drop_duplicates(subset=['team_id']).copy()
    df_teams_unicos['possui_redirection'] = df_teams_unicos['team_id'].apply(
        lambda x: 'Com Redirection' if x in teams_com_redirection else 'Sem Redirection'
    )

    df_agrupado = df_teams_unicos.groupby('possui_redirection').agg(
        vitorias=('wins', 'sum'),
        derrotas=('losses', 'sum'),
        qtd_times=('team_id', 'count')
    ).reset_index()

    todas_categorias = pd.DataFrame({'possui_redirection': ['Com Redirection', 'Sem Redirection']})
    df_agrupado = pd.merge(todas_categorias, df_agrupado, on='possui_redirection', how='left').fillna(0)

    df_agrupado['winrate'] = 0.0
    mask = (df_agrupado['vitorias'] + df_agrupado['derrotas']) > 0
    df_agrupado.loc[mask, 'winrate'] = (df_agrupado['vitorias'] / (df_agrupado['vitorias'] + df_agrupado['derrotas'])) * 100

    total_v = df_agrupado['vitorias'].sum()
    total_d = df_agrupado['derrotas'].sum()
    media_geral_winrate = (total_v / (total_v + total_d)) * 100 if (total_v + total_d) > 0 else 0

    plt.style.use('dark_background')
    plt.figure(figsize=(10, 7))
    
    sns.set_theme(style="darkgrid", rc={
        "axes.facecolor": "#121212", "figure.facecolor": "#121212",
        "text.color": "white", "axes.labelcolor": "white",
        "xtick.color": "white", "ytick.color": "white"
    })

    cores = ['#2ECC71' if x == 'Com Redirection' else '#E74C3C' for x in df_agrupado['possui_redirection']]
    
    ax = sns.barplot(
        x='possui_redirection', 
        y='winrate', 
        data=df_agrupado, 
        palette=cores, 
        hue='possui_redirection', 
        legend=False
    )
    
    if media_geral_winrate > 0:
        plt.axhline(media_geral_winrate, color='#F1C40F', linestyle='--', linewidth=1.5, alpha=0.8)
        plt.text(-0.45, media_geral_winrate + 0.5, f"Média Geral: {media_geral_winrate:.2f}%", color='#F1C40F', weight='bold')

    for p in ax.patches:
        height = p.get_height()
        tipo = df_agrupado['possui_redirection'].iloc[int(p.get_x() + 0.5)]
        qtd = int(df_agrupado[df_agrupado['possui_redirection'] == tipo]['qtd_times'].iloc[0])
        ax.annotate(f"{height:.2f}%\n({qtd} times)", (p.get_x() + p.get_width() / 2., max(height / 2, 5)),
                    ha='center', va='center', fontsize=11, fontweight='bold', color='white')

    plt.title("Impacto do Redirection (Follow Me / Rage Powder) no Winrate da Delphox", fontsize=14, weight='bold', pad=15)
    plt.xlabel("Estrutura do Time", weight='bold', fontsize=11)
    plt.ylabel("Winrate Médio Ponderado (%)", weight='bold', fontsize=11)
    plt.ylim(0, 100)

    plt.tight_layout()
    plt.show()

gerar_grafico_redirection_delphox()
# Out:
# 🔮 Buscando e cruzando dados de suporte de Redirection nos times com Delphox...

# %%
from imports.database import Database
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore", category=UserWarning)

def analisar_moves_setup_delphox():
    db = Database()

    query_base = """
    SELECT 
        pt.team_id,
        t.wins,
        t.losses,
        pdata.name AS pokemon_name,
        mdata.name AS move_name
    FROM Pokemon_teams pt
    JOIN Teams t ON pt.team_id = t.id
    JOIN Pokemon_mapping pmap ON pt.pokemon_id = pmap.pokemon_scraper_id
    JOIN Pokemon_data pdata ON pmap.pokemon_api_id = pdata.id
    LEFT JOIN Pokemon_moves pm ON pt.id = pm.idpokemon_team
    LEFT JOIN Moves_mapping mm ON pm.idmove = mm.move_scraper_id
    LEFT JOIN Moves_data mdata ON mm.move_api_id = mdata.id
    WHERE pt.team_id IN (
        SELECT DISTINCT pt2.team_id
        FROM Pokemon_teams pt2
        JOIN Pokemon_mapping pm2 ON pt2.pokemon_id = pm2.pokemon_scraper_id
        JOIN Pokemon_data pd2 ON pm2.pokemon_api_id = pd2.id
        WHERE LOWER(pd2.name) LIKE '%delphox%'
    );
    """
    
    print("🔮 Calculando a distribuição de Usage e Winrate para Delphox (Encore vs Nasty Plot vs Calm Mind)...")
    with db.connect() as cursor:
        df = pd.read_sql_query(query_base, cursor._connection)

    if df.empty:
        print("❌ Nenhum dado encontrado para processar.")
        return

    df_delphox = df[df['pokemon_name'].str.lower().str.contains('delphox')].copy()
    df_delphox['move_clean'] = df_delphox['move_name'].fillna('').str.lower().str.replace('-', ' ').str.strip()

    teams_encore = set(df_delphox[df_delphox['move_clean'].str.contains('encore')]['team_id'].unique())
    teams_nasty = set(df_delphox[df_delphox['move_clean'].str.contains('nasty plot')]['team_id'].unique())
    teams_calm = set(df_delphox[df_delphox['move_clean'].str.contains('calm mind')]['team_id'].unique())

    df_teams_unicos = df.drop_duplicates(subset=['team_id']).copy()
    total_geral_times = len(df_teams_unicos)

    registros_filtrados = []
    for _, row in df_teams_unicos.iterrows():
        t_id = row['team_id']
        if t_id in teams_encore:
            novo_reg = row.to_dict()
            novo_reg['cenario'] = 'Encore'
            registros_filtrados.append(novo_reg)
        if t_id in teams_nasty:
            novo_reg = row.to_dict()
            novo_reg['cenario'] = 'Nasty Plot'
            registros_filtrados.append(novo_reg)
        if t_id in teams_calm:
            novo_reg = row.to_dict()
            novo_reg['cenario'] = 'Calm Mind'
            registros_filtrados.append(novo_reg)

    df_final = pd.DataFrame(registros_filtrados)

    if df_final.empty:
        print("❌ Nenhum time utilizando Encore, Nasty Plot ou Calm Mind foi encontrado.")
        return

    df_agrupado = df_final.groupby('cenario').agg(
        vitorias=('wins', 'sum'),
        derrotas=('losses', 'sum'),
        qtd_times=('team_id', 'count')
    ).reset_index()

    df_agrupado['usage_pct'] = (df_agrupado['qtd_times'] / total_geral_times) * 100
    df_agrupado['winrate'] = (df_agrupado['vitorias'] / (df_agrupado['vitorias'] + df_agrupado['derrotas'])) * 100

    ordem_colunas = ['Encore', 'Nasty Plot', 'Calm Mind']
    df_agrupado['cenario'] = pd.Categorical(df_agrupado['cenario'], categories=ordem_colunas, ordered=True)
    df_agrupado = df_agrupado.sort_values('cenario').reset_index(drop=True)

    total_v_global = df_teams_unicos['wins'].sum()
    total_d_global = df_teams_unicos['losses'].sum()
    media_geral_winrate = (total_v_global / (total_v_global + total_d_global)) * 100

    fig, ax = plt.subplots(figsize=(11, 7))
    fig.patch.set_facecolor('#141517')
    ax.set_facecolor('#1b1c1e')

    paleta_cores = {
        'Encore': '#2b786a',
        'Nasty Plot': '#3b6475',
        'Calm Mind': '#6c5274'
    }
    
    cor_texto = "#cccccc"
    cor_grade = "#282a2d"

    sns.barplot(
        x='cenario', 
        y='winrate', 
        data=df_agrupado, 
        palette=paleta_cores, 
        hue='cenario', 
        legend=False,
        alpha=0.9,
        ax=ax
    )
    
    plt.axhline(media_geral_winrate, color='#b09646', linestyle=':', linewidth=1.5, alpha=0.7)
    plt.text(-0.4, media_geral_winrate + 0.8, f"Média Geral Delphox: {media_geral_winrate:.2f}%", color='#b09646', weight='bold', fontsize=9)

    ax.tick_params(colors=cor_texto)
    ax.grid(True, linestyle="--", color=cor_grade, alpha=0.6, axis='y')

    for p in ax.patches:
        height = p.get_height()
        if height <= 0:
            continue
        idx = int(p.get_x() + 0.5)
        if idx >= len(df_agrupado):
            continue
        dado = df_agrupado.iloc[idx]
        
        ax.annotate(f"Winrate: {height:.2f}%\nUso: {dado['usage_pct']:.1f}%\n({int(dado['qtd_times'])} times)", 
                    (p.get_x() + p.get_width() / 2., height / 2),
                    ha='center', va='center', fontsize=10, fontweight='bold', color=cor_texto)

    plt.title("Comparativo: Encore vs Nasty Plot vs Calm Mind na Delphox", fontsize=13, weight='bold', pad=20, color=cor_texto)
    plt.xlabel("Movimento Escolhido", weight='bold', fontsize=11, color=cor_texto, labelpad=10)
    plt.ylabel("Winrate Médio Ponderado (%)", weight='bold', fontsize=11, color=cor_texto, labelpad=10)
    plt.ylim(0, 100)

    plt.tight_layout()
    plt.show()

analisar_moves_setup_delphox()
# Out:
# 🔮 Calculando a distribuição de Usage e Winrate para Delphox (Encore vs Nasty Plot vs Calm Mind)...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from imports.database import Database
from imports.constants import MEGA_STONES

warnings.filterwarnings("ignore", category=UserWarning)

def analisar_co_megas_delphox():
    db = Database()
    
    # Prepara a tupla formatada para injeção segura na clausula IN do SQL
    mega_stones_tuple = tuple(MEGA_STONES)
    
    query = f"""
    WITH DelphoxTeams AS (
        -- Isola apenas os times que possuem o Mega Delphox (Delphoxite)
        SELECT DISTINCT pt.team_id
        FROM Pokemon_teams pt
        JOIN Items i ON pt.item_id = i.id
        JOIN Pokemon_mapping pm ON pt.pokemon_id = pm.pokemon_scraper_id
        JOIN Pokemon_data pd ON pm.pokemon_api_id = pd.id
        WHERE LOWER(pd.name) LIKE '%delphox%' 
          AND LOWER(i.name) LIKE '%delphoxite%'
    ),
    OtherMegas AS (
        -- Busca a OUTRA Mega Stone no mesmo time utilizando a constante MEGA_STONES
        SELECT 
            dt.team_id,
            t.wins,
            t.losses,
            pd.name AS mega_name
        FROM DelphoxTeams dt
        JOIN Teams t ON dt.team_id = t.id
        JOIN Pokemon_teams pt ON dt.team_id = pt.team_id
        JOIN Items i ON pt.item_id = i.id
        JOIN Pokemon_mapping pm ON pt.pokemon_id = pm.pokemon_scraper_id
        JOIN Pokemon_data pd ON pm.pokemon_api_id = pd.id
        WHERE i.name IN {mega_stones_tuple}
          AND LOWER(pd.name) NOT LIKE '%delphox%' -- Exclui o próprio Delphox da contagem
    ),
    TotalDelphox AS (
        -- Total de times com Mega Delphox para calculo percentual de Usage
        SELECT COUNT(*) AS total_teams FROM DelphoxTeams
    )
    SELECT 
        om.mega_name AS mega,
        COUNT(om.team_id) AS qtd_times,
        ROUND(100.0 * COUNT(om.team_id) / NULLIF((SELECT total_teams FROM TotalDelphox), 0), 2) AS usage_rate,
        ROUND(100.0 * SUM(om.wins) / NULLIF(SUM(om.wins) + SUM(om.losses), 0), 2) AS winrate
    FROM OtherMegas om
    GROUP BY om.mega_name
    ORDER BY qtd_times DESC;
    """
    
    print("🔮 Conectando ao banco e analisando co-Megas do Mega Delphox (via MEGA_STONES)...")
    with db.connect() as cursor:
        df_local = pd.read_sql_query(query, cursor._connection)
        
    if df_local.empty:
        print("❌ Nenhuma outra Mega encontrada nos times de Mega Delphox.")
        return None
        
    return df_local

df = analisar_co_megas_delphox()

if df is not None and not df.empty:
    sns.set_theme(style="darkgrid", rc={
        "axes.facecolor": "#121212", 
        "figure.facecolor": "#121212",
        "text.color": "white",
        "axes.labelcolor": "white",
        "xtick.color": "white",
        "ytick.color": "white"
    })

    fig, axes = plt.subplots(1, 2, figsize=(16, 6))
    fig.suptitle('Análise de Co-Megas: Sinergias com Mega Delphox', fontsize=16, fontweight='bold', color='#FFFFFF', y=1.02)

    # Gráfico 1: Popularidade (Usage Rate)
    sns.barplot(x='usage_rate', y='mega', data=df, ax=axes[0], palette='Oranges_r', hue='mega', legend=False)
    axes[0].set_title('Popularidade (% de Usage nos times de Delphox)', fontsize=13, color='#E67E22', weight='bold', pad=12)
    axes[0].set_xlabel('Usage Rate (%)', weight='bold')
    axes[0].set_ylabel('Parceiro Mega', weight='bold')
    
    for p in axes[0].patches:
        width = p.get_width()
        if width > 0:
            axes[0].annotate(f"{width:.1f}%", (width + 0.5, p.get_y() + p.get_height()/2.),
                            ha='left', va='center', fontsize=10, fontweight='bold', color='white')

    # Gráfico 2: Winrate
    df_win = df.sort_values(by='winrate', ascending=False)
    sns.barplot(x='winrate', y='mega', data=df_win, ax=axes[1], palette='Blues_r', hue='mega', legend=False)
    axes[1].set_title('Eficiência (Winrate Médio da Dupla)', fontsize=13, color='#3498DB', weight='bold', pad=12)
    axes[1].set_xlabel('Winrate (%)', weight='bold')
    axes[1].set_ylabel('')
    
    axes[1].axvline(50, color='red', linestyle='--', alpha=0.5)

    for p in axes[1].patches:
        width = p.get_width()
        if width > 0:
            axes[1].annotate(f"{width:.1f}%", (width + 0.5, p.get_y() + p.get_height()/2.),
                            ha='left', va='center', fontsize=10, fontweight='bold', color='white')

    plt.tight_layout()
    
    save_path = '../sql/delphox_co_megas_analysis.png'
    plt.savefig(save_path, dpi=300, bbox_inches='tight')
    print(f"\n📊 Gráfico de análise de co-megas salvo com sucesso em: {save_path}")
    plt.show()
# Out:
# 🔮 Conectando ao banco e analisando co-Megas do Mega Delphox (via MEGA_STONES)...
#
# 📊 Gráfico de análise de co-megas salvo com sucesso em: ../sql/delphox_co_megas_analysis.png

# %%
from imports.database import Database
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

def analisar_arqueticos_de_times_correto():
    db = Database()
    
    query = """
    WITH ClassificacaoMoves AS (
        SELECT 
            pt.team_id,
            pt.id AS pokemon_team_id,
            md.damage_class
        FROM Pokemon_moves pm
        JOIN Pokemon_teams pt ON pm.idpokemon_team = pt.id
        JOIN Moves m ON pm.idmove = m.id
        JOIN Moves_mapping mm ON m.id = mm.move_scraper_id
        JOIN Moves_data md ON mm.move_api_id = md.id
        WHERE LOWER(md.name) NOT LIKE '%protect%'
          AND LOWER(md.name) NOT LIKE '%detect%'
          AND LOWER(md.name) NOT LIKE '%spiky shield%'
          AND LOWER(md.name) NOT LIKE '%baneful bunker%'
          AND LOWER(md.name) NOT LIKE '%kings shield%'
    ),
    ContagemPokemon AS (
        SELECT 
            team_id,
            pokemon_team_id,
            SUM(CASE WHEN LOWER(damage_class) = 'physical' THEN 1 ELSE 0 END) AS qtd_phys,
            SUM(CASE WHEN LOWER(damage_class) = 'special' THEN 1 ELSE 0 END) AS qtd_spec,
            SUM(CASE WHEN LOWER(damage_class) = 'status' THEN 1 ELSE 0 END) AS qtd_status
        FROM ClassificacaoMoves
        GROUP BY team_id, pokemon_team_id
    ),
    PapelPokemon AS (
        SELECT 
            team_id,
            CASE 
                WHEN qtd_status >= qtd_phys AND qtd_status >= qtd_spec THEN 'Support'
                WHEN qtd_phys >= qtd_spec THEN 'Physical'
                ELSE 'Special'
            END AS papel
        FROM ContagemPokemon
    ),
    DistribuicaoTime AS (
        SELECT 
            team_id,
            SUM(CASE WHEN papel = 'Physical' THEN 1 ELSE 0 END) AS phys_slots,
            SUM(CASE WHEN papel = 'Special' THEN 1 ELSE 0 END) AS spec_slots,
            SUM(CASE WHEN papel = 'Support' THEN 1 ELSE 0 END) AS supp_slots
        FROM PapelPokemon
        GROUP BY team_id
    )
    SELECT 
        dt.team_id,
        t.wins,
        t.losses,
        CONCAT(dt.phys_slots, 'F / ', dt.spec_slots, 'E / ', dt.supp_slots, 'S') AS distribuicao,
        ROUND(100.0 * t.wins / NULLIF(t.wins + t.losses, 0), 2) AS winrate
    FROM DistribuicaoTime dt
    JOIN Teams t ON dt.team_id = t.id
    WHERE (t.wins + t.losses) > 0;
    """
    
    print("Buscando dados das táticas de times no banco...")
    with db.connect() as cursor:
        conexao = cursor._connection
        df_local = pd.read_sql_query(query, conexao)
        
    return df_local

df_teams = analisar_arqueticos_de_times_correto()

if df_teams is not None and not df_teams.empty:
    def extrair_e_somar_slots(dist_string):
        try:
            numeros = [int(s) for s in dist_string.replace('F', '').replace('E', '').replace('S', '').split('/')]
            return sum(numeros)
        except:
            return 0

    df_teams['total_pokemon'] = df_teams['distribuicao'].apply(extrair_e_somar_slots)
    df_perfeitos = df_teams[df_teams['total_pokemon'] == 6].copy()
    
    contagem_dist = df_perfeitos['distribuicao'].value_counts()
    dist_validas = contagem_dist[contagem_dist >= 5].index
    df_filtrado = df_perfeitos[df_perfeitos['distribuicao'].isin(dist_validas)]
    ordem_popularidade = df_filtrado['distribuicao'].value_counts().index
    
    media_winrate_geral = df_filtrado['winrate'].mean()

    plt.style.use('dark_background')
    sns.set_theme(style="darkgrid", rc={
        "axes.facecolor": "#121212", "figure.facecolor": "#121212",
        "text.color": "white", "axes.labelcolor": "white",
        "xtick.color": "white", "ytick.color": "white"
    })

    fig, axes = plt.subplots(2, 1, figsize=(16, 14))
    fig.suptitle('Distribuição de arquiteturas de times com Delphox', fontsize=18, fontweight='bold', y=0.96)

    sns.boxplot(x='distribuicao', y='winrate', data=df_filtrado, order=ordem_popularidade, ax=axes[0], palette='viridis', hue='distribuicao', legend=False)
    axes[0].set_xlabel('')
    axes[0].set_ylabel('Winrate (%)', weight='bold')
    axes[0].axhline(50, color='red', linestyle='--', alpha=0.5)
    axes[0].set_xticklabels(ordem_popularidade, rotation=35, ha='right')

    df_usage = df_filtrado['distribuicao'].value_counts(normalize=True).reset_index()
    df_usage.columns = ['distribuicao', 'usage_pct']
    df_usage['usage_pct'] *= 100

    sns.barplot(x='distribuicao', y='usage_pct', data=df_usage, order=ordem_popularidade, ax=axes[1], palette='magma', hue='distribuicao', legend=False)
    axes[1].set_title('Frequência de Uso Real com Linha de Referência de Winrate Geral', fontsize=14, color='#E67E22', weight='bold')
    axes[1].set_xlabel('Distribuição (Físico / Especial / Suporte)', weight='bold')
    axes[1].set_ylabel('Presença no Meta (%)', color='#E67E22', weight='bold')
    axes[1].set_xticklabels(ordem_popularidade, rotation=35, ha='right')

    ax2 = axes[1].twinx()
    ax2.set_ylabel('Escala de Winrate (%)', color='#2ECC71', weight='bold')
    ax2.set_ylim(0, 100)
    ax2.tick_params(axis='y', labelcolor='#2ECC71')
    ax2.grid(False)

    ax2.axhline(media_winrate_geral, color='#2ECC71', linestyle='--', linewidth=2, alpha=0.8, 
                label=f'Média de Winrate Geral ({media_winrate_geral:.2f}%)')
    
    ax2.legend(loc='upper right')

    for p in axes[1].patches:
        height = p.get_height()
        if height > 0:
            axes[1].annotate(f"{height:.2f}%", (p.get_x() + p.get_width() / 2., height + 0.3),
                        ha='center', va='center', fontsize=9, fontweight='bold', color='white')

    plt.tight_layout()
    plt.show()
# Out:
# Buscando dados das táticas de times no banco...

# %%
from imports.database import Database
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore", category=UserWarning)

def gerar_boxplot_times_completos_delphox():
    db = Database()
    
    query = """
    SELECT 
        pt.team_id,
        pdata.name AS pokemon_name,
        t.wins,
        t.losses,
        ROUND(100.0 * t.wins / NULLIF(t.wins + t.losses, 0), 2) AS winrate
    FROM Pokemon_teams pt
    JOIN Teams t ON pt.team_id = t.id
    JOIN Pokemon_mapping pmap ON pt.pokemon_id = pmap.pokemon_scraper_id
    JOIN Pokemon_data pdata ON pmap.pokemon_api_id = pdata.id
    WHERE pt.team_id IN (
        SELECT DISTINCT pt2.team_id
        FROM Pokemon_teams pt2
        JOIN Pokemon_mapping pm2 ON pt2.pokemon_id = pm2.pokemon_scraper_id
        JOIN Pokemon_data pd2 ON pm2.pokemon_api_id = pd2.id
        WHERE LOWER(pd2.name) LIKE '%delphox%'
    );
    """
    
    print("🔮 Mapeando todas as combinações de quintetos usadas com a Delphox...")
    with db.connect() as cursor:
        df = pd.read_sql_query(query, cursor._connection)
        
    if df.empty:
        print("❌ Nenhum dado encontrado para processar.")
        return

    df_contagem = df.groupby('team_id').size().reset_index(name='qtd')
    teams_6_pokes = df_contagem[df_contagem['qtd'] == 6]['team_id'].tolist()
    df_filtrado = df[df['team_id'].isin(teams_6_pokes)].copy()
    
    total_times_delphox = len(teams_6_pokes)

    df_parceiros = df_filtrado[~df_filtrado['pokemon_name'].str.lower().str.contains('delphox')].copy()
    
    quintetos_list = []
    for t_id, group in df_parceiros.groupby('team_id'):
        nomes_parceiros = sorted(group['pokemon_name'].str.upper().tolist())
        string_quinteto = " | ".join(nomes_parceiros)
        
        winrate = group['winrate'].iloc[0]
        wins = group['wins'].iloc[0]
        losses = group['losses'].iloc[0]
        
        quintetos_list.append({
            'team_id': t_id,
            'quinteto': string_quinteto,
            'winrate': winrate,
            'wins': wins,
            'losses': losses
        })
        
    df_quintetos = pd.DataFrame(quintetos_list)
    
    contagem_quintetos = df_quintetos['quinteto'].value_counts()
    quintetos_populares = contagem_quintetos[contagem_quintetos >= 5].index.tolist()
    
    if not quintetos_populares:
        print("⚠️ Nenhuma combinação idêntica de 5 Pokémon apareceu 5 ou mais vezes. Reduzindo limite para 2...")
        quintetos_populares = contagem_quintetos[contagem_quintetos >= 2].index.tolist()
        
    if not quintetos_populares:
        print("❌ As combinações de times são muito dispersas para gerar o Boxplot.")
        return
        
    df_plot = df_quintetos[df_quintetos['quinteto'].isin(quintetos_populares)].copy()
    
    df_info_labels = df_plot.groupby('quinteto').agg(
        qtd_times=('team_id', 'count'),
        v_tot=('wins', 'sum'),
        d_tot=('losses', 'sum')
    ).reset_index()
    
    df_info_labels['usage_pct'] = (df_info_labels['qtd_times'] / total_times_delphox) * 100
    df_info_labels['wr_ponderado'] = (df_info_labels['v_tot'] / (df_info_labels['v_tot'] + df_info_labels['d_tot'])) * 100
    df_info_labels = df_info_labels.sort_values(by='usage_pct', ascending=False)
    
    mapa_indices = {}
    legenda_lista = []
    
    for idx, row in enumerate(df_info_labels.iterrows(), start=1):
        quinteto_str = row[1]['quinteto']
        usage = row[1]['usage_pct']
        wr = row[1]['wr_ponderado']
        
        label_curto = f"{idx}"
        mapa_indices[quinteto_str] = label_curto
        
        legenda_lista.append(f"📋 {label_curto} [Uso: {usage:.1f}% | WR: {wr:.1f}%]\n   ↳ {quinteto_str}")
        
    df_plot['Quinteto_Curto'] = df_plot['quinteto'].map(mapa_indices)
    ordem_eixo_x = [mapa_indices[q] for q in df_info_labels['quinteto'].tolist()]

    plt.style.use('dark_background')
    plt.figure(figsize=(12, 7))
    
    sns.set_theme(style="darkgrid", rc={
        "axes.facecolor": "#121212", "figure.facecolor": "#121212",
        "text.color": "white", "axes.labelcolor": "white",
        "xtick.color": "white", "ytick.color": "white"
    })

    sns.boxplot(
        x='Quinteto_Curto', 
        y='winrate', 
        data=df_plot, 
        order=ordem_eixo_x, 
        palette='magma', 
        hue='Quinteto_Curto', 
        legend=False
    )
    
    media_delphox_global = (df_quintetos['wins'].sum() / (df_quintetos['wins'].sum() + df_quintetos['losses'].sum())) * 100
    plt.axhline(media_delphox_global, color='#E74C3C', linestyle='--', linewidth=2, alpha=0.7)
    plt.text(-0.45, media_delphox_global + 1.5, f"Média Geral do Ecossistema Delphox: {media_delphox_global:.2f}%", color='#E74C3C', weight='bold', fontsize=11)

    plt.title("Consistência de Winrate por Estrutura de Time (Os 5 Parceiros da Delphox)", fontsize=14, fontweight='bold', pad=15)
    plt.xlabel("Identificação do Grupo de Parceiros (Veja os detalhes na lista abaixo)", weight='bold', fontsize=11)
    plt.ylabel("Variação de Winrate do Time (%)", weight='bold', fontsize=11)
    plt.ylim(0, 100)

    plt.tight_layout()
    plt.show() 

    print("\n🗺️ COMPOSIÇÕES DETALHADAS:")
    print("==========================================================================================")
    print("\n\n".join(legenda_lista))
    print("==========================================================================================")

gerar_boxplot_times_completos_delphox()
# Out:
# 🔮 Mapeando todas as combinações de quintetos usadas com a Delphox...
# 🗺️ COMPOSIÇÕES DETALHADAS:
# ==========================================================================================
# 📋 1 [Uso: 4.4% | WR: 56.0%]
#    ↳ BASCULEGION-MALE | CLEFABLE | DRAGONITE | KINGAMBIT | SNEASLER
#
# 📋 2 [Uso: 2.6% | WR: 48.7%]
#    ↳ FLOETTE-ETERNAL | INCINEROAR | MAUSHOLD-FAMILY-OF-FOUR | SINISTCHA | VIVILLON
#
# 📋 3 [Uso: 2.6% | WR: 57.2%]
#    ↳ BASCULEGION-MALE | CLEFABLE | GARCHOMP | KINGAMBIT | SNEASLER
#
# 📋 4 [Uso: 2.3% | WR: 50.3%]
#    ↳ BASCULEGION-MALE | FLOETTE-ETERNAL | INCINEROAR | SINISTCHA | SNEASLER
#
# 📋 5 [Uso: 1.8% | WR: 49.7%]
#    ↳ AERODACTYL | GARCHOMP | KINGAMBIT | SNEASLER | TSAREENA
#
# 📋 6 [Uso: 1.8% | WR: 54.7%]
#    ↳ AERODACTYL | GARCHOMP | KINGAMBIT | ROTOM-WASH | SNEASLER
#
# 📋 7 [Uso: 1.1% | WR: 52.3%]
#    ↳ FLOETTE-ETERNAL | INCINEROAR | KINGAMBIT | SINISTCHA | SNEASLER
#
# 📋 8 [Uso: 1.0% | WR: 48.9%]
#    ↳ AERODACTYL | BASCULEGION-MALE | GARCHOMP | KINGAMBIT | SNEASLER
#
# 📋 9 [Uso: 1.0% | WR: 54.8%]
#    ↳ CLEFABLE | GARCHOMP | GYARADOS | KINGAMBIT | SNEASLER
#
# 📋 10 [Uso: 0.9% | WR: 52.0%]
#    ↳ AERODACTYL | FLOETTE | GARCHOMP | INCINEROAR | MAUSHOLD-FAMILY-OF-FOUR
#
# 📋 11 [Uso: 0.9% | WR: 60.5%]
#    ↳ AERODACTYL | FLOETTE-ETERNAL | GARCHOMP | KINGAMBIT | SNEASLER
#
# 📋 12 [Uso: 0.9% | WR: 49.2%]
#    ↳ GARCHOMP | KINGAMBIT | ROTOM-WASH | SNEASLER | WHIMSICOTT
#
# 📋 13 [Uso: 0.9% | WR: 45.1%]
#    ↳ BASCULEGION-MALE | GARCHOMP | KINGAMBIT | SNEASLER | WHIMSICOTT
#
# 📋 14 [Uso: 0.8% | WR: 66.0%]
#    ↳ AEGISLASH-SHIELD | BASCULEGION-MALE | FLOETTE | KINGAMBIT | SNEASLER
#
# 📋 15 [Uso: 0.7% | WR: 66.7%]
#    ↳ BASCULEGION-MALE | FLOETTE-MEGA | GARCHOMP | KINGAMBIT | SNEASLER
#
# 📋 16 [Uso: 0.7% | WR: 70.0%]
#    ↳ BASCULEGION-MALE | FLOETTE-ETERNAL | KINGAMBIT | SNEASLER | WHIMSICOTT
#
# 📋 17 [Uso: 0.7% | WR: 52.1%]
#    ↳ BASCULEGION-MALE | CORVIKNIGHT | FLOETTE-ETERNAL | GARCHOMP | MAUSHOLD-FAMILY-OF-FOUR
#
# 📋 18 [Uso: 0.6% | WR: 54.8%]
#    ↳ FLOETTE-ETERNAL | GARCHOMP | INCINEROAR | KINGAMBIT | SNEASLER
#
# 📋 19 [Uso: 0.6% | WR: 50.0%]
#    ↳ KOMMO-O | MANECTRIC | MAUSHOLD-FAMILY-OF-FOUR | TSAREENA | WHIMSICOTT
#
# 📋 20 [Uso: 0.6% | WR: 62.9%]
#    ↳ AERODACTYL | BASCULEGION-MALE | FLOETTE-ETERNAL | KINGAMBIT | SNEASLER
#
# 📋 21 [Uso: 0.6% | WR: 16.7%]
#    ↳ GARCHOMP | MILOTIC | SNEASLER | SYLVEON | TALONFLAME
#
# 📋 22 [Uso: 0.5% | WR: 41.2%]
#    ↳ BASCULEGION-MALE | FROSLASS | GARCHOMP | KINGAMBIT | SNEASLER
#
# 📋 23 [Uso: 0.5% | WR: 46.2%]
#    ↳ GARCHOMP | KINGAMBIT | ROTOM-WASH | SINISTCHA | SNEASLER
#
# 📋 24 [Uso: 0.5% | WR: 56.2%]
#    ↳ BASCULEGION-MALE | FLOETTE | GARCHOMP | KINGAMBIT | SNEASLER
#
# 📋 25 [Uso: 0.5% | WR: 48.6%]
#    ↳ AEGISLASH-SHIELD | AERODACTYL | GARCHOMP | KANGASKHAN | MILOTIC
#
# 📋 26 [Uso: 0.5% | WR: 44.0%]
#    ↳ GARCHOMP | GENGAR | MEOWSCARADA | MILOTIC | WHIMSICOTT
#
# 📋 27 [Uso: 0.4% | WR: 63.3%]
#    ↳ AERODACTYL | BASCULEGION-MALE | FLOETTE-ETERNAL | GARCHOMP | MAUSHOLD-FAMILY-OF-FOUR
#
# 📋 28 [Uso: 0.4% | WR: 58.7%]
#    ↳ AERODACTYL | BASCULEGION-MALE | CLEFABLE | KINGAMBIT | SNEASLER
#
# 📋 29 [Uso: 0.4% | WR: 55.3%]
#    ↳ GARCHOMP | GYARADOS | KINGAMBIT | SINISTCHA | SNEASLER
#
# 📋 30 [Uso: 0.4% | WR: 56.2%]
#    ↳ GARCHOMP | KINGAMBIT | NINETALES-ALOLA | ROTOM-WASH | SNEASLER
#
# 📋 31 [Uso: 0.4% | WR: 59.1%]
#    ↳ BASCULEGION-MALE | FLOETTE-ETERNAL | GARCHOMP | KINGAMBIT | SNEASLER
#
# 📋 32 [Uso: 0.4% | WR: 62.8%]
#    ↳ AERODACTYL | FLOETTE-MEGA | GARCHOMP | INCINEROAR | MAUSHOLD-FAMILY-OF-FOUR
#
# 📋 33 [Uso: 0.4% | WR: 64.1%]
#    ↳ GARCHOMP | KINGAMBIT | ROTOM-WASH | SNEASLER | TSAREENA
#
# 📋 34 [Uso: 0.4% | WR: 65.5%]
#    ↳ FLOETTE-ETERNAL | GARCHOMP | KINGAMBIT | ROTOM-WASH | SNEASLER
#
# 📋 35 [Uso: 0.4% | WR: 77.1%]
#    ↳ AERODACTYL | FLOETTE-MEGA | KINGAMBIT | MAUSHOLD-FAMILY-OF-FOUR | SNEASLER
#
# 📋 36 [Uso: 0.4% | WR: 66.7%]
#    ↳ BASCULEGION-MALE | GARCHOMP | KINGAMBIT | SINISTCHA | SNEASLER
#
# 📋 37 [Uso: 0.3% | WR: 75.9%]
#    ↳ AEGISLASH-SHIELD | FLOETTE | GARCHOMP | KINGAMBIT | VIVILLON
#
# 📋 38 [Uso: 0.3% | WR: 55.6%]
#    ↳ AEGISLASH-SHIELD | BASCULEGION-MALE | FLOETTE-ETERNAL | KINGAMBIT | SNEASLER
#
# 📋 39 [Uso: 0.3% | WR: 70.0%]
#    ↳ AEGISLASH-SHIELD | GARCHOMP | INCINEROAR | ROTOM-WASH | VENUSAUR
#
# 📋 40 [Uso: 0.3% | WR: 54.5%]
#    ↳ AEGISLASH-SHIELD | FLOETTE-ETERNAL | GARCHOMP | KINGAMBIT | VIVILLON
#
# 📋 41 [Uso: 0.3% | WR: 44.8%]
#    ↳ AERODACTYL | FLOETTE-ETERNAL | GARCHOMP | INCINEROAR | MAUSHOLD-FAMILY-OF-FOUR
#
# 📋 42 [Uso: 0.3% | WR: 45.8%]
#    ↳ AERODACTYL | BASCULEGION-MALE | KINGAMBIT | SNEASLER | TSAREENA
#
# 📋 43 [Uso: 0.3% | WR: 50.0%]
#    ↳ FLOETTE | GARCHOMP | INCINEROAR | KINGAMBIT | SNEASLER
#
# 📋 44 [Uso: 0.3% | WR: 45.7%]
#    ↳ ALAKAZAM | KINGAMBIT | MEOWSTIC-MALE | SNEASLER | WHIMSICOTT
#
# 📋 45 [Uso: 0.3% | WR: 44.8%]
#    ↳ GARCHOMP | GRENINJA | NINETALES-ALOLA | ORTHWORM | SNEASLER
#
# 📋 46 [Uso: 0.3% | WR: 60.7%]
#    ↳ FLOETTE-MEGA | GARCHOMP | INCINEROAR | KINGAMBIT | SNEASLER
#
# 📋 47 [Uso: 0.3% | WR: 60.0%]
#    ↳ FLOETTE-ETERNAL | GARCHOMP | INCINEROAR | SINISTCHA | SNEASLER
#
# 📋 48 [Uso: 0.3% | WR: 41.2%]
#    ↳ GARCHOMP | NINETALES-ALOLA | ROTOM-WASH | SNEASLER | VENUSAUR
# ==========================================================================================

# %%
from imports.database import Database
import pandas as pd
import warnings

warnings.filterwarnings("ignore", category=UserWarning)

def analisar_build_gyarados_com_delphox():
    db = Database()
    
    pd.set_option('display.max_rows', None)
    pd.set_option('display.max_columns', None)
    pd.set_option('display.width', 1000)

    query_equipe = """
    SELECT 
        pt.team_id,
        pdata.name AS pokemon_name
    FROM Pokemon_teams pt
    JOIN Pokemon_mapping pmap ON pt.pokemon_id = pmap.pokemon_scraper_id
    JOIN Pokemon_data pdata ON pmap.pokemon_api_id = pdata.id
    WHERE pt.team_id IN (
        SELECT DISTINCT pt2.team_id
        FROM Pokemon_teams pt2
        JOIN Pokemon_mapping pm2 ON pt2.pokemon_id = pm2.pokemon_scraper_id
        JOIN Pokemon_data pd2 ON pm2.pokemon_api_id = pd2.id
        WHERE LOWER(pd2.name) LIKE '%delphox%'
    );
    """
    
    print("🔍 Localizando registros de times com Delphox e Gyarados...")
    with db.connect() as cursor:
        df_all = pd.read_sql_query(query_equipe, cursor._connection)
        
    if df_all.empty:
        print("❌ Nenhum dado encontrado.")
        return

    times_validos_ids = []
    for t_id, group in df_all.groupby('team_id'):
        nomes_no_time = set(group['pokemon_name'].str.lower().tolist())
        if 'gyarados' in nomes_no_time:
            times_validos_ids.append(t_id)
            
    total_times_alvo = len(times_validos_ids)
    
    if total_times_alvo == 0:
        print("❌ Não foram encontrados times contendo Gyarados junto com a Delphox.")
        return
        
    print(f"✅ Encontrados {total_times_alvo} times com a dupla! Extraindo detalhes das builds...\n")

    where_clause = f"WHERE pt.team_id = {times_validos_ids[0]}" if total_times_alvo == 1 else f"WHERE pt.team_id IN {tuple(times_validos_ids)}"

    query_detalhes = f"""
    SELECT 
        pt.id AS pokemon_team_id,
        pdata.name AS pokemon_name,
        i.name AS item_name,
        mdata.name AS move_name,
        mdata.damage_class
    FROM Pokemon_teams pt
    JOIN Pokemon_mapping pmap ON pt.pokemon_id = pmap.pokemon_scraper_id
    JOIN Pokemon_data pdata ON pmap.pokemon_api_id = pdata.id
    LEFT JOIN Items i ON pt.item_id = i.id
    LEFT JOIN Pokemon_moves pm ON pt.id = pm.idpokemon_team
    LEFT JOIN Moves_mapping mm ON pm.idmove = mm.move_scraper_id
    LEFT JOIN Moves_data mdata ON mm.move_api_id = mdata.id
    {where_clause}
      AND LOWER(pdata.name) = 'gyarados';
    """

    with db.connect() as cursor:
        df_detalhes = pd.read_sql_query(query_detalhes, cursor._connection)

    output_lines = []
    output_lines.append("==========================================================================================")
    output_lines.append(f"RAIO-X DE BUILDS: GYARADOS")
    output_lines.append(f"Foco: Apenas em times acompanhando Delphox (Amostra: {total_times_alvo} times)")
    output_lines.append("==========================================================================================")

    df_poke = df_detalhes[df_detalhes['pokemon_name'].str.lower() == 'gyarados']
    
    if not df_poke.empty:
        output_lines.append(f"\n➔ POKÉMON: GYARADOS")
        output_lines.append("------------------------------------------------------------------------------------------")
        
        df_items_unicos = df_poke.drop_duplicates(subset=['pokemon_team_id'])
        top_items = df_items_unicos['item_name'].value_counts().reset_index()
        top_items.columns = ['item_name', 'count']
        
        output_lines.append("  📦 DISTRIBUIÇÃO DE ITENS:")
        for _, row in top_items.iterrows():
            pct_item = (row['count'] / total_times_alvo) * 100
            item_label = row['item_name'] if pd.notna(row['item_name']) else "Sem Item"
            output_lines.append(f"     • {item_label:<22} -> {pct_item:.1f}% de uso")
            
        top_moves = df_poke['move_name'].value_counts().reset_index()
        top_moves.columns = ['move_name', 'count']
        
        output_lines.append("\n  ⚔️ DISTRIBUIÇÃO DE MOVIMENTOS:")
        for _, row in top_moves.iterrows():
            if pd.isna(row['move_name']):
                continue
            pct_move = (row['count'] / total_times_alvo) * 100
            m_class = df_poke[df_poke['move_name'] == row['move_name']]['damage_class'].iloc[0]
            m_class_label = m_class if pd.notna(m_class) else "Status"
            output_lines.append(f"     • {row['move_name']:<22} [{m_class_label:<8}] -> {pct_move:.1f}% de uso")
        output_lines.append("------------------------------------------------------------------------------------------")

    print("\n".join(output_lines))

analisar_build_gyarados_com_delphox()
# Out:
# 🔍 Localizando registros de times com Delphox e Gyarados...
# ✅ Encontrados 71 times com a dupla! Extraindo detalhes das builds...
#
# ==========================================================================================
# RAIO-X DE BUILDS: GYARADOS
# Foco: Apenas em times acompanhando Delphox (Amostra: 71 times)
# ==========================================================================================
#
# ➔ POKÉMON: GYARADOS
# ------------------------------------------------------------------------------------------
#   📦 DISTRIBUIÇÃO DE ITENS:
#      • Gyaradosite            -> 56.3% de uso
#      • Leftovers              -> 19.7% de uso
#      • Lum Berry              -> 12.7% de uso
#      • Sitrus Berry           -> 8.5% de uso
#      • Quick Claw             -> 1.4% de uso
#      • Mystic Water           -> 1.4% de uso
#
#   ⚔️ DISTRIBUIÇÃO DE MOVIMENTOS:
#      • waterfall              [physical] -> 98.6% de uso
#      • protect                [status  ] -> 81.7% de uso
#      • dragon-dance           [status  ] -> 57.7% de uso
#      • crunch                 [physical] -> 52.1% de uso
#      • taunt                  [status  ] -> 32.4% de uso
#      • thunder-wave           [status  ] -> 31.0% de uso
#      • helping-hand           [status  ] -> 9.9% de uso
#      • icy-wind               [special ] -> 8.5% de uso
#      • ice-fang               [physical] -> 5.6% de uso
#      • lash-out               [physical] -> 4.2% de uso
#      • sandstorm              [status  ] -> 4.2% de uso
#      • bulldoze               [physical] -> 4.2% de uso
#      • power-whip             [physical] -> 2.8% de uso
#      • fire-blast             [special ] -> 1.4% de uso
#      • aqua-tail              [physical] -> 1.4% de uso
#      • rain-dance             [status  ] -> 1.4% de uso
#      • earthquake             [physical] -> 1.4% de uso
#      • temper-flare           [physical] -> 1.4% de uso
# ------------------------------------------------------------------------------------------
